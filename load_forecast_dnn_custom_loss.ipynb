# %% [markdown]
# The notebook must be run several times to produce the "model_name_results.csv" files.
#
# For each run, change the "penalty_" variable and rerun the notebook.

# %%
# define the penalty (or premium if <1) for under-predicting.
penalty_ = 1.5

# %% [markdown]
# # 0 Modules, path, etc

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import modules
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import data_table

# use data table provided by Colab
data_table.enable_dataframe_formatter()

# %% [markdown]
# Run the following line if the Colab start having trouble navigating directories.

# %%
# reset the path
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# check directory
# !pwd
# Out:
# /content

# %%
# set directory
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# The panel.csv contains:
#
# *   **Labels:** Load (electricity demand in MW) for different weather zones in Texas. The Weather Zones are shown in the figure below.
# *   **Inputs:** Weather data (temperature, dew, humidity, etc) taken from the four largest cities in the state (Dallas, Houston, San Antonio and Austin).

# %%
# inputs
x = pd.read_csv("panel.csv")
x
# Out:
# Warning: total number of rows (61344) exceeds max_rows (20000). Falling back to pandas display.
#          load_coast  cloudcover_houston  dew_houston  feelslike_houston  \
# 0       7607.189871                64.6         19.8               20.0
# 1       7389.267519                65.5         19.3               20.0
# 2       7179.748411               100.0         19.0               19.4
# 3       7039.692524               100.0         18.3               18.5
# 4       6991.412764               100.0         15.9               16.1
# ...             ...                 ...          ...                ...
# 61339  11109.257860                 7.3         -6.6               13.9
# 61340  10846.500060                 6.1         -5.5               13.8
# 61341  10592.539870                 7.3         -5.3               12.9
# 61342  10304.624870                 9.2         -2.5               12.9
# 61343  10019.771130                97.5         -1.6               12.9
#
#        humidity_houston  precip_houston  sealevelpressure_houston  \
# 0                 98.78           0.000                    1013.6
# 1                 95.76           0.014                    1013.6
# 2                 97.31           0.000                    1013.9
# 3                 99.10           1.863                    1013.7
# 4                 99.12           1.546                    1013.6
# ...                 ...             ...                       ...
# 61339             23.66           0.000                    1021.8
# 61340             25.77           0.000                    1022.0
# 61341             27.81           0.000                    1022.0
# 61342             34.29           0.000                    1022.0
# 61343             36.78           0.000                    1022.0
#
#        solarradiation_houston  temp_houston  visibility_houston  \
# 0                         0.0          20.0                 8.6
# 1                         0.0          20.0                 6.0
# 2                         0.0          19.4                 3.5
# 3                         0.0          18.5                 3.1
# 4                         0.0          16.1                 9.5
# ...                       ...           ...                 ...
# 61339                     0.0          13.9                16.0
# 61340                     0.0          13.8                16.0
# 61341                     0.0          12.9                13.3
# 61342                     0.0          12.9                 8.8
# 61343                     0.0          12.9                16.0
#
#        windspeed_houston  hour day_name  weekend  month  year  season  \
# 0                   11.0     0  Tuesday    False      1  2013  winter
# 1                    9.2     1  Tuesday    False      1  2013  winter
# 2                   10.2     2  Tuesday    False      1  2013  winter
# 3                   17.6     3  Tuesday    False      1  2013  winter
# 4                   22.7     4  Tuesday    False      1  2013  winter
# ...                  ...   ...      ...      ...    ...   ...     ...
# 61339                0.0    19  Tuesday    False     12  2019  winter
# 61340                0.8    20  Tuesday    False     12  2019  winter
# 61341                1.0    21  Tuesday    False     12  2019  winter
# 61342                5.6    22  Tuesday    False     12  2019  winter
# 61343                5.4    23  Tuesday    False     12  2019  winter
#
#                       date
# 0      2013-01-01 00:00:00
# 1      2013-01-01 01:00:00
# 2      2013-01-01 02:00:00
# 3      2013-01-01 03:00:00
# 4      2013-01-01 04:00:00
# ...                    ...
# 61339  2019-12-31 19:00:00
# 61340  2019-12-31 20:00:00
# 61341  2019-12-31 21:00:00
# 61342  2019-12-31 22:00:00
# 61343  2019-12-31 23:00:00
#
# [61344 rows x 18 columns]

# %% [markdown]
# Clean the data, normalize it.

# %%
# check for nans
x.isna().sum()
x = x.dropna()

# fix dates
x['date'] = pd.to_datetime(x['date'], infer_datetime_format=True)

# set index
x = x.set_index('date')

# restrict the amount of data used
x = x.loc[(2014 <= x.index.year) & (x.index.year <= 2018)]

# add year as explanatory variable
x['year'] = x.index.year - min(x.index.year)

# sort everything
x = x.sort_values(["date"])

# splits labels and inputs
y = x.filter(like='load')

# take the categorical data off
cat = ['day_name','weekend','month','season']
x_cat = x[cat].astype(str)
x_cat = pd.get_dummies(x_cat)
x = x.drop(cat,axis=1)

# normalize data
x_mean = x.mean()
y_mean = y.mean()
x_std  = x.std()
y_std  = y.std()
x = (x - x_mean) / x_std
y = (y - y_mean) / y_std
# norm_x = (norm_x * x_std) + x_mean

# put the categorical variables back
x = pd.concat([x,x_cat],axis=1)

# choose labels and inputs
y = y[['load_coast']]

# free memory
del cat, x_cat
# Out:
# <ipython-input-62-bb49e16bf337>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['year'] = x.index.year - min(x.index.year)

# %% [markdown]
# Put the data in time series format, use the last "n_past" steps to predict the next "n_future" observations.

# %%
# setting step size
n_past = 96
n_future = 24

# put data in (n_obs x timesteps x n_features)
x_ts = []
y_ts = []
for i in range(n_past, len(x) - (n_future + 1)):
    x_ts.append(x.iloc[(i-n_past):i,0:x.shape[1]])
    y_ts.append(y.iloc[(i):(i+n_future), :])

# transform everything to numpy arrays
x_ts, y_ts = np.array(x_ts), np.array(y_ts)
y_ts = y_ts[:,:,0]

# %% [markdown]
# Split the train and test datasets.

# %%
# train the model using the initial 1500 days
x_train = x_ts[:36000]
y_train = y_ts[:36000]

# validate the model using the final one years
x_test = x_ts[36000:x_ts.shape[0]]
y_test = y_ts[36000:y_ts.shape[0]]

# number of inputs and labels
n_inputs = x.shape[1]
n_labels = y.shape[1]

# %%
# check
print('x_train shape:', x_train.shape)
print('x_train types:', x_train.dtype)
print('y_train types:', y_train.dtype)
# Out:
# x_train shape: (36000, 96, 38)
# x_train types: float64
# y_train types: float64

# %% [markdown]
# # 2 Deep Learning Model

# %% [markdown]
# Set the Tensor Processing Units.

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
tpu_worker = 'grpc://' + os.environ['COLAB_TPU_ADDR']

# get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_worker)

# connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

# set the distribution strategy
strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# WARNING:tensorflow:TPU system grpc://10.120.27.218:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.

# %% [markdown]
# Define the loss functions

# %%
# custom mse with penalty
def penalized_mse(y_true,y_pred):
    penalty = penalty_
    diff = tf.subtract(y_true, y_pred)
    loss = tf.where(tf.greater(diff,0.0), diff * penalty_, diff)
    squared = tf.square(loss)
    return tf.reduce_mean(squared)

# test the penalized mse
print(penalized_mse([[2.0]],[[1.0]]))
print(penalized_mse([[1.0]],[[2.0]]))
# Out:
# tf.Tensor(2.25, shape=(), dtype=float32)
# tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# Import the ingredients used in the model.

# %%
# import things from Keras and TensorFlow
from keras.models    import Sequential
from keras.layers    import Conv1D, LSTM, Dense, Dropout, Flatten, Input
from keras.callbacks import ReduceLROnPlateau
from keras           import backend as K

# %%
#set model for tpu
with strategy.scope():

  model = Sequential([
      Input(shape=(x_train.shape[1], x_train.shape[2])),
      Flatten(),
      Dense(1024, activation='relu'),
      Dropout(0.1),
      Dense(512, activation='relu'),
      Dropout(0.1),
      Dense(256, activation='relu'),
      Dropout(0.1),
      Dense(128, activation='relu'),
      Dropout(0.1),
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(y_train.shape[1])
  ])

  # compile the model
  model.compile(optimizer = 'adam', loss = penalized_mse, metrics = ['mae','mse','mape'])
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.5, beta_1=1e-6)
  reduce_learning_rate = ReduceLROnPlateau(monitor='val_mae',factor=0.2, patience=10, mode='auto')

# # check if inputs and outputs are coherent
# model.summary()

# %%
# use model weights from the case where penalty_ = 1 to speed up things
model.load_weights('weights/dnn.h5')

# %%
# %%time

# model fit
history = model.fit(
    x_train, 
    y_train, 
    validation_split=0.1, 
    verbose=1, 
    epochs=50,
    batch_size = 32,
    shuffle=False,
    validation_data = (x_test, y_test),
    callbacks=[reduce_learning_rate]
    )
# Out:
# Epoch 1/50
# 1125/1125 [==============================] - 22s 16ms/step - loss: 0.1428 - mae: 0.2455 - mse: 0.1060 - mape: 153.1873 - val_loss: 0.2647 - val_mae: 0.3143 - val_mse: 0.1711 - val_mape: 170.4590 - lr: 0.0010
# Epoch 2/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1493 - mae: 0.2555 - mse: 0.1097 - mape: 158.7103 - val_loss: 0.2553 - val_mae: 0.3297 - val_mse: 0.1881 - val_mape: 180.7984 - lr: 0.0010
# Epoch 3/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1513 - mae: 0.2586 - mse: 0.1124 - mape: 159.5569 - val_loss: 0.2666 - val_mae: 0.3431 - val_mse: 0.1964 - val_mape: 188.7124 - lr: 0.0010
# Epoch 4/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1498 - mae: 0.2577 - mse: 0.1118 - mape: 157.7461 - val_loss: 0.2730 - val_mae: 0.3358 - val_mse: 0.1910 - val_mape: 179.2893 - lr: 0.0010
# Epoch 5/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1465 - mae: 0.2552 - mse: 0.1093 - mape: 164.0545 - val_loss: 0.2532 - val_mae: 0.3116 - val_mse: 0.1701 - val_mape: 170.6246 - lr: 0.0010
# Epoch 6/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1493 - mae: 0.2581 - mse: 0.1113 - mape: 158.6382 - val_loss: 0.2479 - val_mae: 0.3346 - val_mse: 0.1920 - val_mape: 192.2941 - lr: 0.0010
# Epoch 7/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1535 - mae: 0.2591 - mse: 0.1152 - mape: 158.7116 - val_loss: 0.2794 - val_mae: 0.3286 - val_mse: 0.1910 - val_mape: 187.7854 - lr: 0.0010
# Epoch 8/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1481 - mae: 0.2565 - mse: 0.1105 - mape: 154.9225 - val_loss: 0.2845 - val_mae: 0.3584 - val_mse: 0.2180 - val_mape: 206.3144 - lr: 0.0010
# Epoch 9/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1465 - mae: 0.2554 - mse: 0.1092 - mape: 157.2768 - val_loss: 0.2893 - val_mae: 0.3418 - val_mse: 0.2039 - val_mape: 211.7877 - lr: 0.0010
# Epoch 10/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1495 - mae: 0.2576 - mse: 0.1120 - mape: 162.5679 - val_loss: 0.2307 - val_mae: 0.3169 - val_mse: 0.1722 - val_mape: 185.3287 - lr: 0.0010
# Epoch 11/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1481 - mae: 0.2572 - mse: 0.1104 - mape: 156.7945 - val_loss: 0.2742 - val_mae: 0.3533 - val_mse: 0.2053 - val_mape: 211.3907 - lr: 0.0010
# Epoch 12/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1558 - mae: 0.2623 - mse: 0.1164 - mape: 159.7884 - val_loss: 0.3034 - val_mae: 0.3496 - val_mse: 0.1975 - val_mape: 173.0944 - lr: 0.0010
# Epoch 13/50
# 1125/1125 [==============================] - 15s 13ms/step - loss: 0.1497 - mae: 0.2578 - mse: 0.1113 - mape: 159.5362 - val_loss: 0.2360 - val_mae: 0.3227 - val_mse: 0.1738 - val_mape: 178.3397 - lr: 0.0010
# Epoch 14/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1481 - mae: 0.2571 - mse: 0.1106 - mape: 153.4039 - val_loss: 0.3234 - val_mae: 0.3640 - val_mse: 0.2362 - val_mape: 232.9245 - lr: 0.0010
# Epoch 15/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1526 - mae: 0.2601 - mse: 0.1143 - mape: 156.3608 - val_loss: 0.2804 - val_mae: 0.3559 - val_mse: 0.2205 - val_mape: 236.9353 - lr: 0.0010
# Epoch 16/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1590 - mae: 0.2689 - mse: 0.1204 - mape: 159.7719 - val_loss: 0.2443 - val_mae: 0.3543 - val_mse: 0.2071 - val_mape: 203.5236 - lr: 2.0000e-04
# Epoch 17/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1456 - mae: 0.2559 - mse: 0.1091 - mape: 154.5601 - val_loss: 0.2308 - val_mae: 0.3377 - val_mse: 0.1922 - val_mape: 192.4483 - lr: 2.0000e-04
# Epoch 18/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1398 - mae: 0.2503 - mse: 0.1048 - mape: 151.6160 - val_loss: 0.2269 - val_mae: 0.3312 - val_mse: 0.1854 - val_mape: 185.5042 - lr: 2.0000e-04
# Epoch 19/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1343 - mae: 0.2458 - mse: 0.1009 - mape: 151.7860 - val_loss: 0.2243 - val_mae: 0.3234 - val_mse: 0.1805 - val_mape: 184.6346 - lr: 2.0000e-04
# Epoch 20/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1313 - mae: 0.2429 - mse: 0.0987 - mape: 151.3454 - val_loss: 0.2214 - val_mae: 0.3205 - val_mse: 0.1781 - val_mape: 179.9050 - lr: 2.0000e-04
# Epoch 21/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1309 - mae: 0.2416 - mse: 0.0979 - mape: 148.1314 - val_loss: 0.2162 - val_mae: 0.3157 - val_mse: 0.1723 - val_mape: 179.7258 - lr: 2.0000e-04
# Epoch 22/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1285 - mae: 0.2401 - mse: 0.0965 - mape: 149.6568 - val_loss: 0.2156 - val_mae: 0.3171 - val_mse: 0.1753 - val_mape: 184.5050 - lr: 2.0000e-04
# Epoch 23/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1263 - mae: 0.2375 - mse: 0.0946 - mape: 147.5726 - val_loss: 0.2123 - val_mae: 0.3094 - val_mse: 0.1682 - val_mape: 180.6809 - lr: 2.0000e-04
# Epoch 24/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1246 - mae: 0.2357 - mse: 0.0934 - mape: 144.4378 - val_loss: 0.2154 - val_mae: 0.3093 - val_mse: 0.1674 - val_mape: 180.2310 - lr: 2.0000e-04
# Epoch 25/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1247 - mae: 0.2360 - mse: 0.0933 - mape: 147.4673 - val_loss: 0.2169 - val_mae: 0.3114 - val_mse: 0.1713 - val_mape: 180.7962 - lr: 2.0000e-04
# Epoch 26/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1235 - mae: 0.2348 - mse: 0.0926 - mape: 144.4773 - val_loss: 0.2156 - val_mae: 0.3103 - val_mse: 0.1703 - val_mape: 176.6066 - lr: 2.0000e-04
# Epoch 27/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1224 - mae: 0.2333 - mse: 0.0918 - mape: 145.6385 - val_loss: 0.2163 - val_mae: 0.3082 - val_mse: 0.1673 - val_mape: 176.6561 - lr: 2.0000e-04
# Epoch 28/50
# 1125/1125 [==============================] - 15s 13ms/step - loss: 0.1216 - mae: 0.2329 - mse: 0.0912 - mape: 143.2591 - val_loss: 0.2170 - val_mae: 0.3114 - val_mse: 0.1708 - val_mape: 178.5754 - lr: 2.0000e-04
# Epoch 29/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1218 - mae: 0.2330 - mse: 0.0912 - mape: 143.0688 - val_loss: 0.2177 - val_mae: 0.3108 - val_mse: 0.1695 - val_mape: 176.3453 - lr: 2.0000e-04
# Epoch 30/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1201 - mae: 0.2313 - mse: 0.0898 - mape: 143.5643 - val_loss: 0.2169 - val_mae: 0.3099 - val_mse: 0.1687 - val_mape: 176.6825 - lr: 2.0000e-04
# Epoch 31/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1195 - mae: 0.2307 - mse: 0.0899 - mape: 143.6428 - val_loss: 0.2149 - val_mae: 0.3068 - val_mse: 0.1677 - val_mape: 172.3126 - lr: 2.0000e-04
# Epoch 32/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1182 - mae: 0.2295 - mse: 0.0886 - mape: 142.5788 - val_loss: 0.2136 - val_mae: 0.3038 - val_mse: 0.1629 - val_mape: 170.9778 - lr: 2.0000e-04
# Epoch 33/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1178 - mae: 0.2293 - mse: 0.0883 - mape: 144.9594 - val_loss: 0.2220 - val_mae: 0.3049 - val_mse: 0.1646 - val_mape: 172.2094 - lr: 2.0000e-04
# Epoch 34/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1183 - mae: 0.2292 - mse: 0.0885 - mape: 141.8273 - val_loss: 0.2227 - val_mae: 0.3133 - val_mse: 0.1728 - val_mape: 180.2630 - lr: 2.0000e-04
# Epoch 35/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1159 - mae: 0.2275 - mse: 0.0870 - mape: 142.1989 - val_loss: 0.2257 - val_mae: 0.3070 - val_mse: 0.1681 - val_mape: 175.6721 - lr: 2.0000e-04
# Epoch 36/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1174 - mae: 0.2283 - mse: 0.0877 - mape: 140.8718 - val_loss: 0.2217 - val_mae: 0.3050 - val_mse: 0.1655 - val_mape: 170.9766 - lr: 2.0000e-04
# Epoch 37/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1169 - mae: 0.2276 - mse: 0.0874 - mape: 142.0100 - val_loss: 0.2281 - val_mae: 0.3114 - val_mse: 0.1714 - val_mape: 175.7687 - lr: 2.0000e-04
# Epoch 38/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1163 - mae: 0.2279 - mse: 0.0873 - mape: 138.4712 - val_loss: 0.2245 - val_mae: 0.3145 - val_mse: 0.1742 - val_mape: 178.1450 - lr: 2.0000e-04
# Epoch 39/50
# 1125/1125 [==============================] - 15s 13ms/step - loss: 0.1147 - mae: 0.2263 - mse: 0.0861 - mape: 137.4463 - val_loss: 0.2224 - val_mae: 0.3100 - val_mse: 0.1711 - val_mape: 175.6104 - lr: 2.0000e-04
# Epoch 40/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1145 - mae: 0.2262 - mse: 0.0858 - mape: 137.2264 - val_loss: 0.2203 - val_mae: 0.3104 - val_mse: 0.1705 - val_mape: 176.9720 - lr: 2.0000e-04
# Epoch 41/50
# 1125/1125 [==============================] - 15s 14ms/step - loss: 0.1145 - mae: 0.2258 - mse: 0.0860 - mape: 139.8399 - val_loss: 0.2174 - val_mae: 0.3091 - val_mse: 0.1679 - val_mape: 172.5258 - lr: 2.0000e-04
# Epoch 42/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1145 - mae: 0.2253 - mse: 0.0857 - mape: 136.3368 - val_loss: 0.2085 - val_mae: 0.3041 - val_mse: 0.1627 - val_mape: 171.0715 - lr: 2.0000e-04
# Epoch 43/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1172 - mae: 0.2301 - mse: 0.0888 - mape: 139.2698 - val_loss: 0.2057 - val_mae: 0.2861 - val_mse: 0.1480 - val_mape: 160.0900 - lr: 4.0000e-05
# Epoch 44/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1147 - mae: 0.2263 - mse: 0.0862 - mape: 136.6942 - val_loss: 0.2051 - val_mae: 0.2850 - val_mse: 0.1477 - val_mape: 158.4440 - lr: 4.0000e-05
# Epoch 45/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1138 - mae: 0.2254 - mse: 0.0853 - mape: 135.9055 - val_loss: 0.2057 - val_mae: 0.2851 - val_mse: 0.1478 - val_mape: 159.2371 - lr: 4.0000e-05
# Epoch 46/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1112 - mae: 0.2234 - mse: 0.0837 - mape: 136.1728 - val_loss: 0.2052 - val_mae: 0.2843 - val_mse: 0.1474 - val_mape: 157.9181 - lr: 4.0000e-05
# Epoch 47/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1117 - mae: 0.2236 - mse: 0.0840 - mape: 137.8469 - val_loss: 0.2056 - val_mae: 0.2849 - val_mse: 0.1479 - val_mape: 157.6982 - lr: 4.0000e-05
# Epoch 48/50
# 1125/1125 [==============================] - 15s 13ms/step - loss: 0.1117 - mae: 0.2231 - mse: 0.0838 - mape: 135.8019 - val_loss: 0.2079 - val_mae: 0.2858 - val_mse: 0.1492 - val_mape: 158.3269 - lr: 4.0000e-05
# Epoch 49/50
# 1125/1125 [==============================] - 15s 13ms/step - loss: 0.1124 - mae: 0.2237 - mse: 0.0842 - mape: 137.6110 - val_loss: 0.2052 - val_mae: 0.2859 - val_mse: 0.1495 - val_mape: 159.2229 - lr: 4.0000e-05
# Epoch 50/50
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.1113 - mae: 0.2229 - mse: 0.0837 - mape: 136.1046 - val_loss: 0.2060 - val_mae: 0.2853 - val_mse: 0.1487 - val_mape: 158.5127 - lr: 4.0000e-05
# CPU times: user 6min 42s, sys: 1min 41s, total: 8min 23s
# Wall time: 13min 11s

# %% [markdown]
# Save the model weights.

# %%
# save model
model_name = 'dnn_custom_loss_' + str(penalty_) + '_penalty'
model.save_weights('weights/' + model_name + '.h5', overwrite=True)

# %%
# export history
hist_df = pd.DataFrame(history.history)
hist_df.to_csv('histories/' + model_name + '_history.csv')

# %% [markdown]
# # 3 Export Results.

# %% [markdown]
# Run this cell if loading weights.

# %%
model.load_weights('weights/' + model_name + '.h5')

# %% [markdown]
# Forecasting and model evaluation

# %%
# model predictions
y_fit = model.predict(x_test)
# Out:
# 241/241 [==============================] - 3s 9ms/step

# %% [markdown]
# Descale the forecasted values.

# %%
# descale the predictions
y_fit = (y_fit * y_std[0]) + y_mean[0]
y_test = (y_test * y_std[0]) + y_mean[0]

# %% [markdown]
# These are the dates where the forecasting starts.
#
# For example, "2016-10-01 02:00:00" means that the first forecasted hour is 2 AM of date 2016-10-01.

# %%
# first forecasted datetime
y_dates = []
for i in range(n_past, len(x) - (n_future + 1)):
    y_dates.append(y.index[i])

# put results in a dataframe
results = pd.DataFrame(index=y_dates)
results.index.name = 'datetime'
results = results[36000:x_ts.shape[0]]

# drop results and actual values for all forecasted hours
for h in range(0,y_fit.shape[1]):
  results['fit_' + str(h)] = y_fit[:,h]
  results['actual_' + str(h)] = y_test[:,h]

# export results
results.to_csv('results/' + model_name + '_results.csv')

# %% [markdown]
# # 4 Error Graphs

# %%
# plot
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_mse'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.savefig('graphs/' + model_name + '_training.pdf')

# %%
# plot
plt.figure(figsize=(20,3))
plt.plot(y_test[0:1500,0], label='Actual')
plt.plot(y_fit[0:1500,0], label='Forecast')
plt.xlabel('Hour')
plt.ylabel('Load (MW)')
plt.legend()
plt.grid(True)
plt.savefig('graphs/' + model_name + '_fit.pdf')

# %%
# comparison between predicted and actual values
plt.figure(figsize=(20,10))
a = plt.axes(aspect='equal')
plt.scatter(y_test[:], y_fit[:])
b = np.linspace(*a.get_xlim())
a.plot(b, b, color='black')
plt.xlabel('True Value (MW)')
plt.ylabel('Predictions (MW)')
plt.savefig('graphs/' + model_name + '_comparison.pdf')

# %%
# error histogram
from matplotlib.ticker import PercentFormatter
error = (y_fit - y_test).flatten()
plt.hist(error, bins = 50, weights=np.ones(len(error)) / len(error))
plt.xlabel("Prediction Error (MW)")
_ = plt.ylabel("Percentage")
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.savefig('graphs/' + model_name + '_errordist.pdf')
