# %% [markdown]
# # 0 Modules, path, etc

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import modules
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import data_table

# use data table provided by Colab
data_table.enable_dataframe_formatter()

# %% [markdown]
# Run the following line if the Colab start having trouble navigating directories.

# %%
# reset the path
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# check directory
# !pwd
# Out:
# /content

# %%
# set directory
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# The panel.csv contains:
#
# *   **Labels:** Load (electricity demand in MW) for different weather zones in Texas. The Weather Zones are shown in the figure below.
# *   **Inputs:** Weather data (temperature, dew, humidity, etc) taken from the four largest cities in the state (Dallas, Houston, San Antonio and Austin).

# %%
# inputs
x = pd.read_csv("panel.csv")
x
# Out:
# Warning: total number of rows (61344) exceeds max_rows (20000). Falling back to pandas display.
#          load_coast  cloudcover_houston  dew_houston  feelslike_houston  \
# 0       7607.189871                64.6         19.8               20.0
# 1       7389.267519                65.5         19.3               20.0
# 2       7179.748411               100.0         19.0               19.4
# 3       7039.692524               100.0         18.3               18.5
# 4       6991.412764               100.0         15.9               16.1
# ...             ...                 ...          ...                ...
# 61339  11109.257860                 7.3         -6.6               13.9
# 61340  10846.500060                 6.1         -5.5               13.8
# 61341  10592.539870                 7.3         -5.3               12.9
# 61342  10304.624870                 9.2         -2.5               12.9
# 61343  10019.771130                97.5         -1.6               12.9
#
#        humidity_houston  precip_houston  sealevelpressure_houston  \
# 0                 98.78           0.000                    1013.6
# 1                 95.76           0.014                    1013.6
# 2                 97.31           0.000                    1013.9
# 3                 99.10           1.863                    1013.7
# 4                 99.12           1.546                    1013.6
# ...                 ...             ...                       ...
# 61339             23.66           0.000                    1021.8
# 61340             25.77           0.000                    1022.0
# 61341             27.81           0.000                    1022.0
# 61342             34.29           0.000                    1022.0
# 61343             36.78           0.000                    1022.0
#
#        solarradiation_houston  temp_houston  visibility_houston  \
# 0                         0.0          20.0                 8.6
# 1                         0.0          20.0                 6.0
# 2                         0.0          19.4                 3.5
# 3                         0.0          18.5                 3.1
# 4                         0.0          16.1                 9.5
# ...                       ...           ...                 ...
# 61339                     0.0          13.9                16.0
# 61340                     0.0          13.8                16.0
# 61341                     0.0          12.9                13.3
# 61342                     0.0          12.9                 8.8
# 61343                     0.0          12.9                16.0
#
#        windspeed_houston  hour day_name  weekend  month  year  season  \
# 0                   11.0     0  Tuesday    False      1  2013  winter
# 1                    9.2     1  Tuesday    False      1  2013  winter
# 2                   10.2     2  Tuesday    False      1  2013  winter
# 3                   17.6     3  Tuesday    False      1  2013  winter
# 4                   22.7     4  Tuesday    False      1  2013  winter
# ...                  ...   ...      ...      ...    ...   ...     ...
# 61339                0.0    19  Tuesday    False     12  2019  winter
# 61340                0.8    20  Tuesday    False     12  2019  winter
# 61341                1.0    21  Tuesday    False     12  2019  winter
# 61342                5.6    22  Tuesday    False     12  2019  winter
# 61343                5.4    23  Tuesday    False     12  2019  winter
#
#                       date
# 0      2013-01-01 00:00:00
# 1      2013-01-01 01:00:00
# 2      2013-01-01 02:00:00
# 3      2013-01-01 03:00:00
# 4      2013-01-01 04:00:00
# ...                    ...
# 61339  2019-12-31 19:00:00
# 61340  2019-12-31 20:00:00
# 61341  2019-12-31 21:00:00
# 61342  2019-12-31 22:00:00
# 61343  2019-12-31 23:00:00
#
# [61344 rows x 18 columns]

# %% [markdown]
# Clean the data, normalize it.

# %%
# check for nans
x.isna().sum()
x = x.dropna()

# fix dates
x['date'] = pd.to_datetime(x['date'], infer_datetime_format=True)

# set index
x = x.set_index('date')

# restrict the amount of data used
x = x.loc[(2014 <= x.index.year) & (x.index.year <= 2018)]

# add year as explanatory variable
x['year'] = x.index.year - min(x.index.year)

# sort everything
x = x.sort_values(["date"])

# splits labels and inputs
y = x.filter(like='load')

# take the categorical data off
cat = ['day_name','weekend','month','season']
x_cat = x[cat].astype(str)
x_cat = pd.get_dummies(x_cat)
x = x.drop(cat,axis=1)

# normalize data
x_mean = x.mean()
y_mean = y.mean()
x_std  = x.std()
y_std  = y.std()
x = (x - x_mean) / x_std
y = (y - y_mean) / y_std
# norm_x = (norm_x * x_std) + x_mean

# put the categorical variables back
x = pd.concat([x,x_cat],axis=1)

# choose labels and inputs
y = y[['load_coast']]

# free memory
del cat, x_cat

# %% [markdown]
# Put the data in time series format, use the last "n_past" steps to predict the next "n_future" observations.

# %%
# setting step size
n_past = 96
n_future = 24

# put data in (n_obs x timesteps x n_features)
x_ts = []
y_ts = []
for i in range(n_past, len(x) - (n_future + 1)):
    x_ts.append(x.iloc[(i-n_past):i,0:x.shape[1]])
    y_ts.append(y.iloc[(i):(i+n_future), :])

# transform everything to numpy arrays
x_ts, y_ts = np.array(x_ts), np.array(y_ts)
y_ts = y_ts[:,:,0]

# %% [markdown]
# Split the train and test datasets.

# %%
# train the model using the initial 1000 days
x_train = x_ts[:36000]
y_train = y_ts[:36000]

# validate the model using the final two years
x_test = x_ts[36000:x_ts.shape[0]]
y_test = y_ts[36000:y_ts.shape[0]]

# number of inputs and labels
n_inputs = x.shape[1]
n_labels = y.shape[1]

# %%
# check
print('x_ts shape:', x_ts.shape)
print('x_train shape:', x_train.shape)
print('x_train types:', x_train.dtype)
print('y_train types:', y_train.dtype)
# Out:
# x_ts shape: (43703, 96, 38)
# x_train shape: (36000, 96, 38)
# x_train types: float64
# y_train types: float64

# %% [markdown]
# # 2 Deep Learning Model

# %% [markdown]
# Set the Tensor Processing Units.

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
tpu_worker = 'grpc://' + os.environ['COLAB_TPU_ADDR']

# get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_worker)

# connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

# set the distribution strategy
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# Import the ingredients used in the model.

# %%
# import things from Keras and TensorFlow
from keras.models    import Sequential
from keras.layers    import Conv1D, LSTM, Dense, Dropout, Flatten, Input
from keras.callbacks import ReduceLROnPlateau
from keras           import backend as K

# %%
#set model for tpu
with strategy.scope():

  model = Sequential([
      Input(shape=(x_train.shape[1], x_train.shape[2])),
      Flatten(),
      Dense(1024, activation='relu'),
      Dropout(0.1),
      Dense(512, activation='relu'),
      Dropout(0.1),
      Dense(256, activation='relu'),
      Dropout(0.1),
      Dense(128, activation='relu'),
      Dropout(0.1),
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(y_train.shape[1])
  ])

  # compile the model
  model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae','mse','mape'])
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.5, beta_1=1e-6)
  reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',factor=0.2, patience=10, mode='auto')

# check if inputs and outputs are coherent
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3648)              0
#
#  dense (Dense)               (None, 1024)              3736576
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 4,436,728
# Trainable params: 4,436,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# model fit
history = model.fit(
    x_train, 
    y_train, 
    validation_split=0.1, 
    verbose=1, 
    epochs=100,
    batch_size = 16,
    shuffle=False,
    validation_data = (x_test, y_test),
    callbacks=[reduce_learning_rate]
    )
# Out:
# Epoch 1/100
# 2250/2250 [==============================] - 39s 15ms/step - loss: 0.3868 - mae: 0.4872 - mse: 0.3868 - mape: 246.2713 - val_loss: 1.1624 - val_mae: 0.8002 - val_mse: 1.1624 - val_mape: 229.5600 - lr: 0.0010
# Epoch 2/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.2740 - mae: 0.4094 - mse: 0.2740 - mape: 243.3965 - val_loss: 1.1326 - val_mae: 0.7826 - val_mse: 1.1326 - val_mape: 301.7086 - lr: 0.0010
# Epoch 3/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.2411 - mae: 0.3823 - mse: 0.2411 - mape: 242.7955 - val_loss: 0.8163 - val_mae: 0.6778 - val_mse: 0.8163 - val_mape: 287.3237 - lr: 0.0010
# Epoch 4/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.2243 - mae: 0.3673 - mse: 0.2243 - mape: 230.4005 - val_loss: 0.9825 - val_mae: 0.7122 - val_mse: 0.9825 - val_mape: 302.4617 - lr: 0.0010
# Epoch 5/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.2085 - mae: 0.3532 - mse: 0.2085 - mape: 218.9873 - val_loss: 0.5006 - val_mae: 0.5324 - val_mse: 0.5006 - val_mape: 251.8723 - lr: 0.0010
# Epoch 6/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1905 - mae: 0.3367 - mse: 0.1905 - mape: 216.6080 - val_loss: 0.4136 - val_mae: 0.4825 - val_mse: 0.4136 - val_mape: 234.7328 - lr: 0.0010
# Epoch 7/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1806 - mae: 0.3267 - mse: 0.1806 - mape: 205.4880 - val_loss: 0.3831 - val_mae: 0.4649 - val_mse: 0.3831 - val_mape: 248.4064 - lr: 0.0010
# Epoch 8/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1731 - mae: 0.3194 - mse: 0.1731 - mape: 202.3954 - val_loss: 0.3640 - val_mae: 0.4490 - val_mse: 0.3640 - val_mape: 249.8238 - lr: 0.0010
# Epoch 9/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1668 - mae: 0.3137 - mse: 0.1668 - mape: 193.8523 - val_loss: 0.3500 - val_mae: 0.4458 - val_mse: 0.3500 - val_mape: 255.8904 - lr: 0.0010
# Epoch 10/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1624 - mae: 0.3093 - mse: 0.1624 - mape: 197.0279 - val_loss: 0.2998 - val_mae: 0.4172 - val_mse: 0.2998 - val_mape: 234.7962 - lr: 0.0010
# Epoch 11/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1621 - mae: 0.3091 - mse: 0.1621 - mape: 195.8458 - val_loss: 0.2805 - val_mae: 0.4101 - val_mse: 0.2805 - val_mape: 242.8876 - lr: 0.0010
# Epoch 12/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1565 - mae: 0.3041 - mse: 0.1565 - mape: 184.0411 - val_loss: 0.2770 - val_mae: 0.4025 - val_mse: 0.2770 - val_mape: 227.7201 - lr: 0.0010
# Epoch 13/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1489 - mae: 0.2963 - mse: 0.1489 - mape: 185.5798 - val_loss: 0.2647 - val_mae: 0.3888 - val_mse: 0.2647 - val_mape: 209.5190 - lr: 0.0010
# Epoch 14/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1451 - mae: 0.2921 - mse: 0.1451 - mape: 180.6888 - val_loss: 0.2794 - val_mae: 0.4010 - val_mse: 0.2794 - val_mape: 239.0589 - lr: 0.0010
# Epoch 15/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1438 - mae: 0.2905 - mse: 0.1438 - mape: 179.4154 - val_loss: 0.2829 - val_mae: 0.3977 - val_mse: 0.2829 - val_mape: 222.0024 - lr: 0.0010
# Epoch 16/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1390 - mae: 0.2865 - mse: 0.1390 - mape: 178.0444 - val_loss: 0.2552 - val_mae: 0.3817 - val_mse: 0.2552 - val_mape: 226.6910 - lr: 0.0010
# Epoch 17/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1389 - mae: 0.2860 - mse: 0.1389 - mape: 174.5728 - val_loss: 0.2678 - val_mae: 0.3955 - val_mse: 0.2678 - val_mape: 223.7505 - lr: 0.0010
# Epoch 18/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1355 - mae: 0.2826 - mse: 0.1355 - mape: 173.0754 - val_loss: 0.2613 - val_mae: 0.3804 - val_mse: 0.2613 - val_mape: 206.8965 - lr: 0.0010
# Epoch 19/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1335 - mae: 0.2808 - mse: 0.1335 - mape: 174.8584 - val_loss: 0.2520 - val_mae: 0.3776 - val_mse: 0.2520 - val_mape: 200.8425 - lr: 0.0010
# Epoch 20/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.1307 - mae: 0.2779 - mse: 0.1307 - mape: 170.6516 - val_loss: 0.2228 - val_mae: 0.3629 - val_mse: 0.2228 - val_mape: 206.0760 - lr: 0.0010
# Epoch 21/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1323 - mae: 0.2790 - mse: 0.1323 - mape: 172.2058 - val_loss: 0.2426 - val_mae: 0.3808 - val_mse: 0.2426 - val_mape: 228.1120 - lr: 0.0010
# Epoch 22/100
# 2250/2250 [==============================] - 34s 15ms/step - loss: 0.1272 - mae: 0.2738 - mse: 0.1272 - mape: 166.7559 - val_loss: 0.2999 - val_mae: 0.4121 - val_mse: 0.2999 - val_mape: 258.4741 - lr: 0.0010
# Epoch 23/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1274 - mae: 0.2737 - mse: 0.1274 - mape: 169.5546 - val_loss: 0.2328 - val_mae: 0.3698 - val_mse: 0.2328 - val_mape: 225.7243 - lr: 0.0010
# Epoch 24/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1311 - mae: 0.2779 - mse: 0.1311 - mape: 172.4603 - val_loss: 0.2651 - val_mae: 0.3797 - val_mse: 0.2651 - val_mape: 224.2646 - lr: 0.0010
# Epoch 25/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1276 - mae: 0.2742 - mse: 0.1276 - mape: 170.5441 - val_loss: 0.2241 - val_mae: 0.3665 - val_mse: 0.2241 - val_mape: 213.3082 - lr: 0.0010
# Epoch 26/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1269 - mae: 0.2728 - mse: 0.1269 - mape: 169.2751 - val_loss: 0.2179 - val_mae: 0.3564 - val_mse: 0.2179 - val_mape: 214.4616 - lr: 0.0010
# Epoch 27/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1268 - mae: 0.2727 - mse: 0.1268 - mape: 168.5087 - val_loss: 0.2202 - val_mae: 0.3658 - val_mse: 0.2202 - val_mape: 177.6089 - lr: 0.0010
# Epoch 28/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1269 - mae: 0.2732 - mse: 0.1269 - mape: 163.0698 - val_loss: 0.1981 - val_mae: 0.3434 - val_mse: 0.1981 - val_mape: 175.7753 - lr: 0.0010
# Epoch 29/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1257 - mae: 0.2719 - mse: 0.1257 - mape: 164.5439 - val_loss: 0.2029 - val_mae: 0.3455 - val_mse: 0.2029 - val_mape: 180.2242 - lr: 0.0010
# Epoch 30/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1277 - mae: 0.2730 - mse: 0.1277 - mape: 164.8613 - val_loss: 0.2046 - val_mae: 0.3464 - val_mse: 0.2046 - val_mape: 213.2143 - lr: 0.0010
# Epoch 31/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1227 - mae: 0.2687 - mse: 0.1227 - mape: 163.3659 - val_loss: 0.2066 - val_mae: 0.3461 - val_mse: 0.2066 - val_mape: 190.2732 - lr: 0.0010
# Epoch 32/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1235 - mae: 0.2695 - mse: 0.1235 - mape: 164.7573 - val_loss: 0.1886 - val_mae: 0.3342 - val_mse: 0.1886 - val_mape: 156.3561 - lr: 0.0010
# Epoch 33/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1236 - mae: 0.2697 - mse: 0.1236 - mape: 163.1305 - val_loss: 0.2180 - val_mae: 0.3517 - val_mse: 0.2180 - val_mape: 200.0469 - lr: 0.0010
# Epoch 34/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1241 - mae: 0.2698 - mse: 0.1241 - mape: 167.2743 - val_loss: 0.2122 - val_mae: 0.3507 - val_mse: 0.2122 - val_mape: 202.0288 - lr: 0.0010
# Epoch 35/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1280 - mae: 0.2737 - mse: 0.1280 - mape: 163.6659 - val_loss: 0.2336 - val_mae: 0.3627 - val_mse: 0.2336 - val_mape: 202.2545 - lr: 0.0010
# Epoch 36/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1199 - mae: 0.2660 - mse: 0.1199 - mape: 165.6791 - val_loss: 0.2026 - val_mae: 0.3397 - val_mse: 0.2026 - val_mape: 213.5868 - lr: 0.0010
# Epoch 37/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1213 - mae: 0.2677 - mse: 0.1213 - mape: 169.5984 - val_loss: 0.2181 - val_mae: 0.3566 - val_mse: 0.2181 - val_mape: 205.7172 - lr: 0.0010
# Epoch 38/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1246 - mae: 0.2713 - mse: 0.1246 - mape: 166.8624 - val_loss: 0.2117 - val_mae: 0.3507 - val_mse: 0.2117 - val_mape: 201.8932 - lr: 0.0010
# Epoch 39/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1238 - mae: 0.2699 - mse: 0.1238 - mape: 163.3010 - val_loss: 0.1916 - val_mae: 0.3289 - val_mse: 0.1916 - val_mape: 208.9156 - lr: 0.0010
# Epoch 40/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1227 - mae: 0.2688 - mse: 0.1227 - mape: 160.3490 - val_loss: 0.2035 - val_mae: 0.3415 - val_mse: 0.2035 - val_mape: 179.2317 - lr: 0.0010
# Epoch 41/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.1216 - mae: 0.2674 - mse: 0.1216 - mape: 162.8782 - val_loss: 0.1832 - val_mae: 0.3244 - val_mse: 0.1832 - val_mape: 176.5048 - lr: 0.0010
# Epoch 42/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1217 - mae: 0.2676 - mse: 0.1217 - mape: 162.6608 - val_loss: 0.2043 - val_mae: 0.3425 - val_mse: 0.2043 - val_mape: 196.8188 - lr: 0.0010
# Epoch 43/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1225 - mae: 0.2676 - mse: 0.1225 - mape: 164.8350 - val_loss: 0.1885 - val_mae: 0.3275 - val_mse: 0.1885 - val_mape: 192.1886 - lr: 0.0010
# Epoch 44/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1206 - mae: 0.2662 - mse: 0.1206 - mape: 161.1705 - val_loss: 0.2173 - val_mae: 0.3474 - val_mse: 0.2173 - val_mape: 194.3740 - lr: 0.0010
# Epoch 45/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1186 - mae: 0.2642 - mse: 0.1186 - mape: 164.8960 - val_loss: 0.2222 - val_mae: 0.3575 - val_mse: 0.2222 - val_mape: 212.0896 - lr: 0.0010
# Epoch 46/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1190 - mae: 0.2649 - mse: 0.1190 - mape: 163.5125 - val_loss: 0.2155 - val_mae: 0.3530 - val_mse: 0.2155 - val_mape: 195.0634 - lr: 0.0010
# Epoch 47/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1203 - mae: 0.2660 - mse: 0.1203 - mape: 167.5694 - val_loss: 0.2095 - val_mae: 0.3420 - val_mse: 0.2095 - val_mape: 181.0111 - lr: 0.0010
# Epoch 48/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1180 - mae: 0.2632 - mse: 0.1180 - mape: 163.1989 - val_loss: 0.2111 - val_mae: 0.3455 - val_mse: 0.2111 - val_mape: 192.6814 - lr: 0.0010
# Epoch 49/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.1165 - mae: 0.2622 - mse: 0.1165 - mape: 169.8878 - val_loss: 0.2041 - val_mae: 0.3407 - val_mse: 0.2041 - val_mape: 199.1498 - lr: 0.0010
# Epoch 50/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.1165 - mae: 0.2619 - mse: 0.1165 - mape: 166.2136 - val_loss: 0.2478 - val_mae: 0.3703 - val_mse: 0.2478 - val_mape: 194.5325 - lr: 0.0010
# Epoch 51/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1204 - mae: 0.2658 - mse: 0.1204 - mape: 163.7903 - val_loss: 0.2225 - val_mae: 0.3558 - val_mse: 0.2225 - val_mape: 210.5910 - lr: 0.0010
# Epoch 52/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1298 - mae: 0.2783 - mse: 0.1298 - mape: 173.2960 - val_loss: 0.2094 - val_mae: 0.3410 - val_mse: 0.2094 - val_mape: 205.9781 - lr: 2.0000e-04
# Epoch 53/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1157 - mae: 0.2618 - mse: 0.1157 - mape: 164.0991 - val_loss: 0.1793 - val_mae: 0.3144 - val_mse: 0.1793 - val_mape: 185.5044 - lr: 2.0000e-04
# Epoch 54/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.1081 - mae: 0.2531 - mse: 0.1081 - mape: 156.1224 - val_loss: 0.1673 - val_mae: 0.3039 - val_mse: 0.1673 - val_mape: 179.8944 - lr: 2.0000e-04
# Epoch 55/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1038 - mae: 0.2479 - mse: 0.1038 - mape: 158.9096 - val_loss: 0.1620 - val_mae: 0.2981 - val_mse: 0.1620 - val_mape: 171.9481 - lr: 2.0000e-04
# Epoch 56/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.1007 - mae: 0.2443 - mse: 0.1007 - mape: 154.2598 - val_loss: 0.1595 - val_mae: 0.2962 - val_mse: 0.1595 - val_mape: 174.4067 - lr: 2.0000e-04
# Epoch 57/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0989 - mae: 0.2419 - mse: 0.0989 - mape: 151.2956 - val_loss: 0.1575 - val_mae: 0.2924 - val_mse: 0.1575 - val_mape: 176.0632 - lr: 2.0000e-04
# Epoch 58/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.0964 - mae: 0.2383 - mse: 0.0964 - mape: 150.8419 - val_loss: 0.1512 - val_mae: 0.2879 - val_mse: 0.1512 - val_mape: 171.9735 - lr: 2.0000e-04
# Epoch 59/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0950 - mae: 0.2369 - mse: 0.0950 - mape: 148.6517 - val_loss: 0.1582 - val_mae: 0.2924 - val_mse: 0.1582 - val_mape: 171.0925 - lr: 2.0000e-04
# Epoch 60/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.0940 - mae: 0.2356 - mse: 0.0940 - mape: 150.1785 - val_loss: 0.1564 - val_mae: 0.2906 - val_mse: 0.1564 - val_mape: 168.3856 - lr: 2.0000e-04
# Epoch 61/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0928 - mae: 0.2340 - mse: 0.0928 - mape: 151.0678 - val_loss: 0.1555 - val_mae: 0.2909 - val_mse: 0.1555 - val_mape: 164.8972 - lr: 2.0000e-04
# Epoch 62/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.0918 - mae: 0.2327 - mse: 0.0918 - mape: 149.1885 - val_loss: 0.1552 - val_mae: 0.2908 - val_mse: 0.1552 - val_mape: 166.6295 - lr: 2.0000e-04
# Epoch 63/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0904 - mae: 0.2313 - mse: 0.0904 - mape: 148.3321 - val_loss: 0.1523 - val_mae: 0.2886 - val_mse: 0.1523 - val_mape: 165.7074 - lr: 2.0000e-04
# Epoch 64/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0896 - mae: 0.2299 - mse: 0.0896 - mape: 148.4498 - val_loss: 0.1576 - val_mae: 0.2924 - val_mse: 0.1576 - val_mape: 166.8377 - lr: 2.0000e-04
# Epoch 65/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0888 - mae: 0.2292 - mse: 0.0888 - mape: 146.0220 - val_loss: 0.1488 - val_mae: 0.2848 - val_mse: 0.1488 - val_mape: 159.8533 - lr: 2.0000e-04
# Epoch 66/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0885 - mae: 0.2287 - mse: 0.0885 - mape: 143.3315 - val_loss: 0.1453 - val_mae: 0.2795 - val_mse: 0.1453 - val_mape: 160.5006 - lr: 2.0000e-04
# Epoch 67/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0884 - mae: 0.2280 - mse: 0.0884 - mape: 142.5278 - val_loss: 0.1473 - val_mae: 0.2814 - val_mse: 0.1473 - val_mape: 161.5822 - lr: 2.0000e-04
# Epoch 68/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0880 - mae: 0.2278 - mse: 0.0880 - mape: 142.8321 - val_loss: 0.1474 - val_mae: 0.2820 - val_mse: 0.1474 - val_mape: 161.8786 - lr: 2.0000e-04
# Epoch 69/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0869 - mae: 0.2263 - mse: 0.0869 - mape: 142.4203 - val_loss: 0.1490 - val_mae: 0.2842 - val_mse: 0.1490 - val_mape: 161.5023 - lr: 2.0000e-04
# Epoch 70/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0864 - mae: 0.2254 - mse: 0.0864 - mape: 142.4107 - val_loss: 0.1499 - val_mae: 0.2852 - val_mse: 0.1499 - val_mape: 163.8676 - lr: 2.0000e-04
# Epoch 71/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0865 - mae: 0.2254 - mse: 0.0865 - mape: 141.4749 - val_loss: 0.1475 - val_mae: 0.2818 - val_mse: 0.1475 - val_mape: 159.5857 - lr: 2.0000e-04
# Epoch 72/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.0850 - mae: 0.2237 - mse: 0.0850 - mape: 140.9000 - val_loss: 0.1496 - val_mae: 0.2837 - val_mse: 0.1496 - val_mape: 163.8275 - lr: 2.0000e-04
# Epoch 73/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0854 - mae: 0.2243 - mse: 0.0854 - mape: 140.2782 - val_loss: 0.1459 - val_mae: 0.2798 - val_mse: 0.1459 - val_mape: 158.7150 - lr: 2.0000e-04
# Epoch 74/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0842 - mae: 0.2227 - mse: 0.0842 - mape: 142.3373 - val_loss: 0.1510 - val_mae: 0.2848 - val_mse: 0.1510 - val_mape: 164.0711 - lr: 2.0000e-04
# Epoch 75/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0842 - mae: 0.2226 - mse: 0.0842 - mape: 141.8045 - val_loss: 0.1531 - val_mae: 0.2865 - val_mse: 0.1531 - val_mape: 162.6741 - lr: 2.0000e-04
# Epoch 76/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0835 - mae: 0.2217 - mse: 0.0835 - mape: 140.7800 - val_loss: 0.1520 - val_mae: 0.2865 - val_mse: 0.1520 - val_mape: 159.6698 - lr: 2.0000e-04
# Epoch 77/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0864 - mae: 0.2265 - mse: 0.0864 - mape: 140.8286 - val_loss: 0.1496 - val_mae: 0.2849 - val_mse: 0.1496 - val_mape: 155.1529 - lr: 4.0000e-05
# Epoch 78/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0845 - mae: 0.2232 - mse: 0.0845 - mape: 139.6951 - val_loss: 0.1473 - val_mae: 0.2817 - val_mse: 0.1473 - val_mape: 153.7885 - lr: 4.0000e-05
# Epoch 79/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0841 - mae: 0.2226 - mse: 0.0841 - mape: 141.3850 - val_loss: 0.1467 - val_mae: 0.2811 - val_mse: 0.1467 - val_mape: 152.2187 - lr: 4.0000e-05
# Epoch 80/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0836 - mae: 0.2219 - mse: 0.0836 - mape: 139.1051 - val_loss: 0.1472 - val_mae: 0.2820 - val_mse: 0.1472 - val_mape: 152.4707 - lr: 4.0000e-05
# Epoch 81/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0825 - mae: 0.2207 - mse: 0.0825 - mape: 138.8401 - val_loss: 0.1456 - val_mae: 0.2800 - val_mse: 0.1456 - val_mape: 151.3986 - lr: 4.0000e-05
# Epoch 82/100
# 2250/2250 [==============================] - 33s 15ms/step - loss: 0.0821 - mae: 0.2203 - mse: 0.0821 - mape: 139.9467 - val_loss: 0.1453 - val_mae: 0.2800 - val_mse: 0.1453 - val_mape: 150.4396 - lr: 4.0000e-05
# Epoch 83/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0823 - mae: 0.2202 - mse: 0.0823 - mape: 143.6929 - val_loss: 0.1449 - val_mae: 0.2798 - val_mse: 0.1449 - val_mape: 150.1830 - lr: 4.0000e-05
# Epoch 84/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0824 - mae: 0.2203 - mse: 0.0824 - mape: 141.7836 - val_loss: 0.1452 - val_mae: 0.2793 - val_mse: 0.1452 - val_mape: 150.9577 - lr: 4.0000e-05
# Epoch 85/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0817 - mae: 0.2194 - mse: 0.0817 - mape: 139.7731 - val_loss: 0.1443 - val_mae: 0.2778 - val_mse: 0.1443 - val_mape: 150.9901 - lr: 4.0000e-05
# Epoch 86/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0810 - mae: 0.2186 - mse: 0.0810 - mape: 141.2180 - val_loss: 0.1459 - val_mae: 0.2798 - val_mse: 0.1459 - val_mape: 151.7615 - lr: 4.0000e-05
# Epoch 87/100
# 2250/2250 [==============================] - 34s 15ms/step - loss: 0.0810 - mae: 0.2187 - mse: 0.0810 - mape: 141.1425 - val_loss: 0.1446 - val_mae: 0.2791 - val_mse: 0.1446 - val_mape: 150.7091 - lr: 4.0000e-05
# Epoch 88/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0809 - mae: 0.2180 - mse: 0.0809 - mape: 139.7635 - val_loss: 0.1446 - val_mae: 0.2792 - val_mse: 0.1446 - val_mape: 150.5657 - lr: 4.0000e-05
# Epoch 89/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0805 - mae: 0.2180 - mse: 0.0805 - mape: 137.9975 - val_loss: 0.1436 - val_mae: 0.2782 - val_mse: 0.1436 - val_mape: 150.1835 - lr: 4.0000e-05
# Epoch 90/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0809 - mae: 0.2182 - mse: 0.0809 - mape: 138.5380 - val_loss: 0.1442 - val_mae: 0.2791 - val_mse: 0.1442 - val_mape: 150.0125 - lr: 4.0000e-05
# Epoch 91/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0806 - mae: 0.2177 - mse: 0.0806 - mape: 140.2563 - val_loss: 0.1438 - val_mae: 0.2775 - val_mse: 0.1438 - val_mape: 150.1564 - lr: 4.0000e-05
# Epoch 92/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0798 - mae: 0.2173 - mse: 0.0798 - mape: 136.9478 - val_loss: 0.1457 - val_mae: 0.2807 - val_mse: 0.1457 - val_mape: 150.3811 - lr: 4.0000e-05
# Epoch 93/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0802 - mae: 0.2174 - mse: 0.0802 - mape: 138.3412 - val_loss: 0.1457 - val_mae: 0.2802 - val_mse: 0.1457 - val_mape: 149.9591 - lr: 4.0000e-05
# Epoch 94/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0798 - mae: 0.2169 - mse: 0.0798 - mape: 138.0748 - val_loss: 0.1462 - val_mae: 0.2805 - val_mse: 0.1462 - val_mape: 150.7378 - lr: 4.0000e-05
# Epoch 95/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0796 - mae: 0.2165 - mse: 0.0796 - mape: 137.4039 - val_loss: 0.1451 - val_mae: 0.2786 - val_mse: 0.1451 - val_mape: 151.6501 - lr: 4.0000e-05
# Epoch 96/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0802 - mae: 0.2173 - mse: 0.0802 - mape: 138.2689 - val_loss: 0.1469 - val_mae: 0.2812 - val_mse: 0.1469 - val_mape: 151.8129 - lr: 4.0000e-05
# Epoch 97/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0792 - mae: 0.2159 - mse: 0.0792 - mape: 135.3994 - val_loss: 0.1460 - val_mae: 0.2805 - val_mse: 0.1460 - val_mape: 150.3887 - lr: 4.0000e-05
# Epoch 98/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0797 - mae: 0.2164 - mse: 0.0797 - mape: 140.5974 - val_loss: 0.1456 - val_mae: 0.2802 - val_mse: 0.1456 - val_mape: 150.7440 - lr: 4.0000e-05
# Epoch 99/100
# 2250/2250 [==============================] - 33s 14ms/step - loss: 0.0792 - mae: 0.2160 - mse: 0.0792 - mape: 138.8172 - val_loss: 0.1469 - val_mae: 0.2819 - val_mse: 0.1469 - val_mape: 150.2907 - lr: 4.0000e-05
# Epoch 100/100
# 2250/2250 [==============================] - 32s 14ms/step - loss: 0.0806 - mae: 0.2181 - mse: 0.0806 - mape: 141.3484 - val_loss: 0.1461 - val_mae: 0.2802 - val_mse: 0.1461 - val_mape: 152.4776 - lr: 8.0000e-06
# CPU times: user 27min 37s, sys: 8min 19s, total: 35min 56s
# Wall time: 54min 50s

# %% [markdown]
# Save the model weights.

# %%
# save model
model.save_weights('dnn.h5', overwrite=True)

# %% [markdown]
# # 3 Error Analysis.

# %% [markdown]
# Run this cell if loading weights.

# %%
# model.load_weights('dnn.h5')

# %% [markdown]
# Forecasting and model evaluation

# %%
# model predictions
y_fit = model.predict(x_test)

# evaluate the model using test data
model.evaluate(x_test, y_test)
# Out:
# 241/241 [==============================] - 4s 10ms/step
# 241/241 [==============================] - 5s 15ms/step - loss: 0.1461 - mae: 0.2802 - mse: 0.1461 - mape: 152.4776
# [0.14607802033424377,
#  0.28022104501724243,
#  0.14607802033424377,
#  152.47764587402344]

# %% [markdown]
# Descale the forecasted values.

# %%
# descale the predictions
y_fit = (y_fit * y_std[0]) + y_mean[0]
y_test = (y_test * y_std[0]) + y_mean[0]

# %% [markdown]
# These are the dates where the forecasting starts.
#
# For example, "2016-10-01 02:00:00" means that the first forecasted hour is 2 AM of date 2016-10-01.

# %%
# first forecasted datetime
y_dates = []
for i in range(n_past, len(x) - (n_future + 1)):
    y_dates.append(y.index[i])

# %%
# put results in a dataframe
results = pd.DataFrame(index=y_dates)
results.index.name = 'datetime'
results = results[36000:x_ts.shape[0]]

# %%
# drop results and actual values for all forecasted hours
for h in range(0,y_fit.shape[1]):
  results['fit_' + str(h)] = y_fit[:,h]
  results['actual_' + str(h)] = y_test[:,h]

# %%
results.to_csv('dnn_results.csv')

# %% [markdown]
# # 4 Error Graphs

# %%
# plot
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.savefig('dnn_training.pdf')

# %%
# plot
plt.figure(figsize=(30,5))
plt.plot(y_test[0:1500,0], label='Actual')
plt.plot(y_fit[0:1500,0], label='Forecast')
plt.xlabel('Hour')
plt.ylabel('Load (MW)')
plt.legend()
plt.grid(True)
plt.savefig('dnn_fit.pdf')

# %%
# comparison between predicted and actual values
plt.figure(figsize=(20,10))
a = plt.axes(aspect='equal')
plt.scatter(y_test[:], y_fit[:])
b = np.linspace(*a.get_xlim())
a.plot(b, b, color='black')
plt.xlabel('True Value (MW)')
plt.ylabel('Predictions (MW)')
plt.savefig('dnn_comparison.pdf')

# %%
# error histogram
from matplotlib.ticker import PercentFormatter
error = (y_fit - y_test).flatten()
plt.hist(error, bins = 50, weights=np.ones(len(error)) / len(error))
plt.xlabel("Prediction Error (MW)")
_ = plt.ylabel("Percentage")
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.savefig('dnn_errordist.pdf')
