# %% [markdown]
# The notebook must be run several times to produce the "model_name_results.csv" files.
#
# For each run, change the "penalty_" variable and rerun the notebook.

# %%
# define the penalty (or premium if <1) for under-predicting.
penalty_ = 1.0

# %% [markdown]
# # 0 Modules, path, etc

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import modules
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import data_table

# use data table provided by Colab
data_table.enable_dataframe_formatter()

# %% [markdown]
# Run the following line if the Colab start having trouble navigating directories.

# %%
# reset the path
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# check directory
# !pwd
# Out:
# /content

# %%
# set directory
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# The panel.csv contains:
#
# *   **Labels:** Load (electricity demand in MW) for different weather zones in Texas. The Weather Zones are shown in the figure below.
# *   **Inputs:** Weather data (temperature, dew, humidity, etc) taken from the four largest cities in the state (Dallas, Houston, San Antonio and Austin).

# %%
# inputs
x = pd.read_csv("panel.csv")
x
# Out:
# Warning: total number of rows (61344) exceeds max_rows (20000). Falling back to pandas display.
#          load_coast  cloudcover_houston  dew_houston  feelslike_houston  \
# 0       7607.189871                64.6         19.8               20.0
# 1       7389.267519                65.5         19.3               20.0
# 2       7179.748411               100.0         19.0               19.4
# 3       7039.692524               100.0         18.3               18.5
# 4       6991.412764               100.0         15.9               16.1
# ...             ...                 ...          ...                ...
# 61339  11109.257860                 7.3         -6.6               13.9
# 61340  10846.500060                 6.1         -5.5               13.8
# 61341  10592.539870                 7.3         -5.3               12.9
# 61342  10304.624870                 9.2         -2.5               12.9
# 61343  10019.771130                97.5         -1.6               12.9
#
#        humidity_houston  precip_houston  sealevelpressure_houston  \
# 0                 98.78           0.000                    1013.6
# 1                 95.76           0.014                    1013.6
# 2                 97.31           0.000                    1013.9
# 3                 99.10           1.863                    1013.7
# 4                 99.12           1.546                    1013.6
# ...                 ...             ...                       ...
# 61339             23.66           0.000                    1021.8
# 61340             25.77           0.000                    1022.0
# 61341             27.81           0.000                    1022.0
# 61342             34.29           0.000                    1022.0
# 61343             36.78           0.000                    1022.0
#
#        solarradiation_houston  temp_houston  visibility_houston  \
# 0                         0.0          20.0                 8.6
# 1                         0.0          20.0                 6.0
# 2                         0.0          19.4                 3.5
# 3                         0.0          18.5                 3.1
# 4                         0.0          16.1                 9.5
# ...                       ...           ...                 ...
# 61339                     0.0          13.9                16.0
# 61340                     0.0          13.8                16.0
# 61341                     0.0          12.9                13.3
# 61342                     0.0          12.9                 8.8
# 61343                     0.0          12.9                16.0
#
#        windspeed_houston  hour day_name  weekend  month  year  season  \
# 0                   11.0     0  Tuesday    False      1  2013  winter
# 1                    9.2     1  Tuesday    False      1  2013  winter
# 2                   10.2     2  Tuesday    False      1  2013  winter
# 3                   17.6     3  Tuesday    False      1  2013  winter
# 4                   22.7     4  Tuesday    False      1  2013  winter
# ...                  ...   ...      ...      ...    ...   ...     ...
# 61339                0.0    19  Tuesday    False     12  2019  winter
# 61340                0.8    20  Tuesday    False     12  2019  winter
# 61341                1.0    21  Tuesday    False     12  2019  winter
# 61342                5.6    22  Tuesday    False     12  2019  winter
# 61343                5.4    23  Tuesday    False     12  2019  winter
#
#                       date
# 0      2013-01-01 00:00:00
# 1      2013-01-01 01:00:00
# 2      2013-01-01 02:00:00
# 3      2013-01-01 03:00:00
# 4      2013-01-01 04:00:00
# ...                    ...
# 61339  2019-12-31 19:00:00
# 61340  2019-12-31 20:00:00
# 61341  2019-12-31 21:00:00
# 61342  2019-12-31 22:00:00
# 61343  2019-12-31 23:00:00
#
# [61344 rows x 18 columns]

# %% [markdown]
# Clean the data, normalize it.

# %%
# check for nans
x.isna().sum()
x = x.dropna()

# fix dates
x['date'] = pd.to_datetime(x['date'], infer_datetime_format=True)

# set index
x = x.set_index('date')

# restrict the amount of data used
x = x.loc[(2014 <= x.index.year) & (x.index.year <= 2018)]

# add year as explanatory variable
x['year'] = x.index.year - min(x.index.year)

# sort everything
x = x.sort_values(["date"])

# splits labels and inputs
y = x.filter(like='load')

# take the categorical data off
cat = ['day_name','weekend','month','season']
x_cat = x[cat].astype(str)
x_cat = pd.get_dummies(x_cat)
x = x.drop(cat,axis=1)

# normalize data
x_mean = x.mean()
y_mean = y.mean()
x_std  = x.std()
y_std  = y.std()
x = (x - x_mean) / x_std
y = (y - y_mean) / y_std
# norm_x = (norm_x * x_std) + x_mean

# put the categorical variables back
x = pd.concat([x,x_cat],axis=1)

# choose labels and inputs
y = y[['load_coast']]

# free memory
del cat, x_cat

# %% [markdown]
# Put the data in time series format, use the last "n_past" steps to predict the next "n_future" observations.

# %%
# setting step size
n_past = 96
n_future = 24

# put data in (n_obs x timesteps x n_features)
x_ts = []
y_ts = []
for i in range(n_past, len(x) - (n_future + 1)):
    x_ts.append(x.iloc[(i-n_past):i,0:x.shape[1]])
    y_ts.append(y.iloc[(i):(i+n_future), :])

# transform everything to numpy arrays
x_ts, y_ts = np.array(x_ts), np.array(y_ts)
y_ts = y_ts[:,:,0]

# %% [markdown]
# Split the train and test datasets.

# %%
# train the model using the initial 1500 days
x_train = x_ts[:36000]
y_train = y_ts[:36000]

# validate the model using the final one years
x_test = x_ts[36000:x_ts.shape[0]]
y_test = y_ts[36000:y_ts.shape[0]]

# number of inputs and labels
n_inputs = x.shape[1]
n_labels = y.shape[1]

# %%
# check
print('x_train shape:', x_train.shape)
print('x_train types:', x_train.dtype)
print('y_train types:', y_train.dtype)
# Out:
# x_train shape: (36000, 96, 38)
# x_train types: float64
# y_train types: float64

# %% [markdown]
# # 2 Deep Learning Model

# %% [markdown]
# Set the Tensor Processing Units.

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
tpu_worker = 'grpc://' + os.environ['COLAB_TPU_ADDR']

# get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_worker)

# connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

# set the distribution strategy
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# Define the loss functions

# %%
# custom mse with penalty
def penalized_mse(y_true,y_pred):
    penalty = penalty_
    diff = tf.subtract(y_true, y_pred)
    loss = tf.where(tf.greater(diff,0.0), diff * penalty_, diff)
    squared = tf.square(loss)
    return tf.reduce_mean(squared)

# test the penalized mse
print(penalized_mse([[2.0]],[[1.0]]))
print(penalized_mse([[1.0]],[[2.0]]))
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32)
# tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# Import the ingredients used in the model.

# %%
# import things from Keras and TensorFlow
from keras.models    import Sequential
from keras.layers    import Conv1D, LSTM, Dense, Dropout, Flatten
from keras.callbacks import ReduceLROnPlateau
from keras           import backend as K

# %%
#set model for tpu
with strategy.scope():

  model = Sequential([
      # Conv1D(filters=64, kernel_size=2,strides=2, padding="valid", activation="relu", input_shape=(x_train.shape[1],x_train.shape[2])),
      # Conv1D(filters=64, kernel_size=1, strides=1, padding="causal", activation="relu"),
      LSTM(48, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])),
      LSTM(256, return_sequences=False),
      # Flatten(),
      Dense(256, activation = "relu"),
      Dropout(0.1),
      Dense(128, activation="relu"),
      Dense(64, activation="relu"),
      Dropout(0.1),
      Dense(32, activation="relu"),
      # Flatten(),
      Dropout(0.1),
      Dense(n_future)
  ])

  # compile the model
  model.compile(optimizer = 'adam', loss = penalized_mse, metrics = ['mae','mse','mape'])
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.5, beta_1=1e-6)
  reduce_learning_rate = ReduceLROnPlateau(monitor='val_mae',factor=0.2, patience=10, mode='auto')

# # check if inputs and outputs are coherent
# model.summary()

# %%
# use model weights from the case where penalty_ = 1 to speed up things
model.load_weights('weights/lstm.h5')

# %%
# %%time

# model fit
history = model.fit(
    x_train, 
    y_train, 
    validation_split=0.1, 
    verbose=1, 
    epochs=50,
    batch_size = 32,
    shuffle=False,
    validation_data = (x_test, y_test),
    callbacks=[reduce_learning_rate]
    )
# Out:
# Epoch 1/50
# 1125/1125 [==============================] - 30s 22ms/step - loss: 0.0488 - mae: 0.1680 - mse: 0.0488 - mape: 109.7760 - val_loss: 0.1445 - val_mae: 0.2766 - val_mse: 0.1445 - val_mape: 150.7970 - lr: 0.0010
# Epoch 2/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0524 - mae: 0.1744 - mse: 0.0524 - mape: 114.4206 - val_loss: 0.1765 - val_mae: 0.3062 - val_mse: 0.1765 - val_mape: 167.7197 - lr: 0.0010
# Epoch 3/50
# 1125/1125 [==============================] - 22s 20ms/step - loss: 0.0506 - mae: 0.1716 - mse: 0.0506 - mape: 110.4802 - val_loss: 0.1961 - val_mae: 0.3231 - val_mse: 0.1961 - val_mape: 211.3063 - lr: 0.0010
# Epoch 4/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0502 - mae: 0.1714 - mse: 0.0502 - mape: 112.7958 - val_loss: 0.1524 - val_mae: 0.2866 - val_mse: 0.1524 - val_mape: 179.5059 - lr: 0.0010
# Epoch 5/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0505 - mae: 0.1721 - mse: 0.0505 - mape: 110.4443 - val_loss: 0.1599 - val_mae: 0.2942 - val_mse: 0.1599 - val_mape: 197.2242 - lr: 0.0010
# Epoch 6/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0512 - mae: 0.1732 - mse: 0.0512 - mape: 108.9710 - val_loss: 0.1662 - val_mae: 0.2998 - val_mse: 0.1662 - val_mape: 187.6690 - lr: 0.0010
# Epoch 7/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0528 - mae: 0.1752 - mse: 0.0528 - mape: 112.9550 - val_loss: 0.1507 - val_mae: 0.2898 - val_mse: 0.1507 - val_mape: 159.3489 - lr: 0.0010
# Epoch 8/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0504 - mae: 0.1713 - mse: 0.0504 - mape: 111.1040 - val_loss: 0.1667 - val_mae: 0.3091 - val_mse: 0.1667 - val_mape: 176.6057 - lr: 0.0010
# Epoch 9/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0513 - mae: 0.1734 - mse: 0.0513 - mape: 110.0196 - val_loss: 0.1936 - val_mae: 0.3254 - val_mse: 0.1936 - val_mape: 178.0713 - lr: 0.0010
# Epoch 10/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0517 - mae: 0.1741 - mse: 0.0517 - mape: 110.8776 - val_loss: 0.1890 - val_mae: 0.3271 - val_mse: 0.1890 - val_mape: 200.6652 - lr: 0.0010
# Epoch 11/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0507 - mae: 0.1731 - mse: 0.0507 - mape: 113.4852 - val_loss: 0.1634 - val_mae: 0.3034 - val_mse: 0.1634 - val_mape: 174.4267 - lr: 0.0010
# Epoch 12/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0535 - mae: 0.1767 - mse: 0.0535 - mape: 112.4276 - val_loss: 0.1518 - val_mae: 0.2808 - val_mse: 0.1518 - val_mape: 166.7968 - lr: 2.0000e-04
# Epoch 13/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0488 - mae: 0.1685 - mse: 0.0488 - mape: 108.6570 - val_loss: 0.1456 - val_mae: 0.2739 - val_mse: 0.1456 - val_mape: 157.1191 - lr: 2.0000e-04
# Epoch 14/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0461 - mae: 0.1637 - mse: 0.0461 - mape: 106.3211 - val_loss: 0.1446 - val_mae: 0.2721 - val_mse: 0.1446 - val_mape: 155.1137 - lr: 2.0000e-04
# Epoch 15/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0449 - mae: 0.1614 - mse: 0.0449 - mape: 103.8552 - val_loss: 0.1455 - val_mae: 0.2728 - val_mse: 0.1455 - val_mape: 158.4920 - lr: 2.0000e-04
# Epoch 16/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0436 - mae: 0.1589 - mse: 0.0436 - mape: 104.5628 - val_loss: 0.1498 - val_mae: 0.2775 - val_mse: 0.1498 - val_mape: 161.7183 - lr: 2.0000e-04
# Epoch 17/50
# 1125/1125 [==============================] - 22s 20ms/step - loss: 0.0436 - mae: 0.1588 - mse: 0.0436 - mape: 103.7956 - val_loss: 0.1457 - val_mae: 0.2737 - val_mse: 0.1457 - val_mape: 156.1749 - lr: 2.0000e-04
# Epoch 18/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0427 - mae: 0.1569 - mse: 0.0427 - mape: 100.7442 - val_loss: 0.1476 - val_mae: 0.2767 - val_mse: 0.1476 - val_mape: 156.6101 - lr: 2.0000e-04
# Epoch 19/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0423 - mae: 0.1562 - mse: 0.0423 - mape: 101.0763 - val_loss: 0.1447 - val_mae: 0.2738 - val_mse: 0.1447 - val_mape: 155.3928 - lr: 2.0000e-04
# Epoch 20/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0417 - mae: 0.1550 - mse: 0.0417 - mape: 101.2884 - val_loss: 0.1465 - val_mae: 0.2758 - val_mse: 0.1465 - val_mape: 156.5137 - lr: 2.0000e-04
# Epoch 21/50
# 1125/1125 [==============================] - 22s 20ms/step - loss: 0.0415 - mae: 0.1547 - mse: 0.0415 - mape: 100.3894 - val_loss: 0.1500 - val_mae: 0.2780 - val_mse: 0.1500 - val_mape: 158.7200 - lr: 2.0000e-04
# Epoch 22/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0411 - mae: 0.1541 - mse: 0.0411 - mape: 100.2437 - val_loss: 0.1481 - val_mae: 0.2773 - val_mse: 0.1481 - val_mape: 157.9439 - lr: 2.0000e-04
# Epoch 23/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0415 - mae: 0.1543 - mse: 0.0415 - mape: 99.7270 - val_loss: 0.1498 - val_mae: 0.2797 - val_mse: 0.1498 - val_mape: 159.5333 - lr: 2.0000e-04
# Epoch 24/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0408 - mae: 0.1533 - mse: 0.0408 - mape: 98.7752 - val_loss: 0.1486 - val_mae: 0.2780 - val_mse: 0.1486 - val_mape: 151.0760 - lr: 2.0000e-04
# Epoch 25/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0429 - mae: 0.1571 - mse: 0.0429 - mape: 97.3010 - val_loss: 0.1456 - val_mae: 0.2730 - val_mse: 0.1456 - val_mape: 144.5061 - lr: 4.0000e-05
# Epoch 26/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0414 - mae: 0.1547 - mse: 0.0414 - mape: 99.0503 - val_loss: 0.1452 - val_mae: 0.2727 - val_mse: 0.1452 - val_mape: 143.9213 - lr: 4.0000e-05
# Epoch 27/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0412 - mae: 0.1541 - mse: 0.0412 - mape: 97.1844 - val_loss: 0.1455 - val_mae: 0.2737 - val_mse: 0.1455 - val_mape: 143.6556 - lr: 4.0000e-05
# Epoch 28/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0407 - mae: 0.1533 - mse: 0.0407 - mape: 96.5275 - val_loss: 0.1435 - val_mae: 0.2712 - val_mse: 0.1435 - val_mape: 143.8321 - lr: 4.0000e-05
# Epoch 29/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0406 - mae: 0.1532 - mse: 0.0406 - mape: 96.9320 - val_loss: 0.1444 - val_mae: 0.2722 - val_mse: 0.1444 - val_mape: 143.8874 - lr: 4.0000e-05
# Epoch 30/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0406 - mae: 0.1528 - mse: 0.0406 - mape: 97.6544 - val_loss: 0.1441 - val_mae: 0.2720 - val_mse: 0.1441 - val_mape: 145.0962 - lr: 4.0000e-05
# Epoch 31/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0410 - mae: 0.1535 - mse: 0.0410 - mape: 97.2837 - val_loss: 0.1448 - val_mae: 0.2726 - val_mse: 0.1448 - val_mape: 144.2345 - lr: 4.0000e-05
# Epoch 32/50
# 1125/1125 [==============================] - 22s 20ms/step - loss: 0.0405 - mae: 0.1527 - mse: 0.0405 - mape: 97.3988 - val_loss: 0.1436 - val_mae: 0.2716 - val_mse: 0.1436 - val_mape: 143.9727 - lr: 4.0000e-05
# Epoch 33/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0407 - mae: 0.1527 - mse: 0.0407 - mape: 98.6182 - val_loss: 0.1440 - val_mae: 0.2715 - val_mse: 0.1440 - val_mape: 145.1754 - lr: 4.0000e-05
# Epoch 34/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0403 - mae: 0.1522 - mse: 0.0403 - mape: 96.3563 - val_loss: 0.1432 - val_mae: 0.2708 - val_mse: 0.1432 - val_mape: 144.3796 - lr: 4.0000e-05
# Epoch 35/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0401 - mae: 0.1521 - mse: 0.0401 - mape: 97.4120 - val_loss: 0.1432 - val_mae: 0.2709 - val_mse: 0.1432 - val_mape: 143.8357 - lr: 4.0000e-05
# Epoch 36/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0398 - mae: 0.1514 - mse: 0.0398 - mape: 98.5734 - val_loss: 0.1439 - val_mae: 0.2721 - val_mse: 0.1439 - val_mape: 144.9290 - lr: 4.0000e-05
# Epoch 37/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0398 - mae: 0.1516 - mse: 0.0398 - mape: 97.5337 - val_loss: 0.1440 - val_mae: 0.2720 - val_mse: 0.1440 - val_mape: 144.6564 - lr: 4.0000e-05
# Epoch 38/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0397 - mae: 0.1511 - mse: 0.0397 - mape: 96.8184 - val_loss: 0.1438 - val_mae: 0.2720 - val_mse: 0.1438 - val_mape: 145.0103 - lr: 4.0000e-05
# Epoch 39/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0393 - mae: 0.1509 - mse: 0.0393 - mape: 95.6366 - val_loss: 0.1439 - val_mae: 0.2722 - val_mse: 0.1439 - val_mape: 143.8039 - lr: 4.0000e-05
# Epoch 40/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0399 - mae: 0.1514 - mse: 0.0399 - mape: 96.6315 - val_loss: 0.1431 - val_mae: 0.2705 - val_mse: 0.1431 - val_mape: 143.4477 - lr: 4.0000e-05
# Epoch 41/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0396 - mae: 0.1512 - mse: 0.0396 - mape: 97.7231 - val_loss: 0.1426 - val_mae: 0.2702 - val_mse: 0.1426 - val_mape: 143.7040 - lr: 4.0000e-05
# Epoch 42/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0399 - mae: 0.1513 - mse: 0.0399 - mape: 96.5835 - val_loss: 0.1428 - val_mae: 0.2703 - val_mse: 0.1428 - val_mape: 143.1967 - lr: 4.0000e-05
# Epoch 43/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0398 - mae: 0.1509 - mse: 0.0398 - mape: 96.3528 - val_loss: 0.1423 - val_mae: 0.2695 - val_mse: 0.1423 - val_mape: 143.4578 - lr: 4.0000e-05
# Epoch 44/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0399 - mae: 0.1516 - mse: 0.0399 - mape: 96.8497 - val_loss: 0.1429 - val_mae: 0.2710 - val_mse: 0.1429 - val_mape: 143.2799 - lr: 4.0000e-05
# Epoch 45/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0392 - mae: 0.1502 - mse: 0.0392 - mape: 96.3347 - val_loss: 0.1425 - val_mae: 0.2703 - val_mse: 0.1425 - val_mape: 143.6199 - lr: 4.0000e-05
# Epoch 46/50
# 1125/1125 [==============================] - 22s 20ms/step - loss: 0.0392 - mae: 0.1502 - mse: 0.0392 - mape: 96.4707 - val_loss: 0.1433 - val_mae: 0.2716 - val_mse: 0.1433 - val_mape: 143.9150 - lr: 4.0000e-05
# Epoch 47/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0398 - mae: 0.1511 - mse: 0.0398 - mape: 95.7215 - val_loss: 0.1431 - val_mae: 0.2708 - val_mse: 0.1431 - val_mape: 144.2307 - lr: 4.0000e-05
# Epoch 48/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0393 - mae: 0.1504 - mse: 0.0393 - mape: 96.5755 - val_loss: 0.1424 - val_mae: 0.2705 - val_mse: 0.1424 - val_mape: 142.8178 - lr: 4.0000e-05
# Epoch 49/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.0393 - mae: 0.1503 - mse: 0.0393 - mape: 97.3701 - val_loss: 0.1427 - val_mae: 0.2701 - val_mse: 0.1427 - val_mape: 143.6059 - lr: 4.0000e-05
# Epoch 50/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.0393 - mae: 0.1504 - mse: 0.0393 - mape: 96.1357 - val_loss: 0.1428 - val_mae: 0.2709 - val_mse: 0.1428 - val_mape: 143.3691 - lr: 4.0000e-05
# CPU times: user 7min 14s, sys: 1min 52s, total: 9min 6s
# Wall time: 18min 16s

# %% [markdown]
# Save the model weights.

# %%
# save model
model_name = 'lstm_custom_loss_' + str(penalty_) + '_penalty'
model.save_weights('weights/' + model_name + '.h5', overwrite=True)

# %%
# export history
hist_df = pd.DataFrame(history.history)
hist_df.to_csv('histories/' + model_name + '_history.csv')

# %% [markdown]
# # 3 Export Results.

# %% [markdown]
# Run this cell if loading weights.

# %%
# model.load_weights('weights/' + model_name + '.h5')

# %% [markdown]
# Forecasting and model evaluation

# %%
# model predictions
y_fit = model.predict(x_test)
# Out:
# 241/241 [==============================] - 3s 10ms/step

# %% [markdown]
# Descale the forecasted values.

# %%
# descale the predictions
y_fit = (y_fit * y_std[0]) + y_mean[0]
y_test = (y_test * y_std[0]) + y_mean[0]

# %% [markdown]
# These are the dates where the forecasting starts.
#
# For example, "2016-10-01 02:00:00" means that the first forecasted hour is 2 AM of date 2016-10-01.

# %%
# first forecasted datetime
y_dates = []
for i in range(n_past, len(x) - (n_future + 1)):
    y_dates.append(y.index[i])

# put results in a dataframe
results = pd.DataFrame(index=y_dates)
results.index.name = 'datetime'
results = results[36000:x_ts.shape[0]]

# drop results and actual values for all forecasted hours
for h in range(0,y_fit.shape[1]):
  results['fit_' + str(h)] = y_fit[:,h]
  results['actual_' + str(h)] = y_test[:,h]

# export results
results.to_csv('results/' + model_name + '_results.csv')

# %% [markdown]
# # 4 Error Graphs

# %%
# plot
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_mse'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.savefig('graphs/' + model_name + '_training.pdf')

# %%
# plot
plt.figure(figsize=(20,3))
plt.plot(y_test[0:1500,0], label='Actual')
plt.plot(y_fit[0:1500,0], label='Forecast')
plt.xlabel('Hour')
plt.ylabel('Load (MW)')
plt.legend()
plt.grid(True)
plt.savefig('graphs/' + model_name + '_fit.pdf')

# %%
# comparison between predicted and actual values
plt.figure(figsize=(20,10))
a = plt.axes(aspect='equal')
plt.scatter(y_test[:], y_fit[:])
b = np.linspace(*a.get_xlim())
a.plot(b, b, color='black')
plt.xlabel('True Value (MW)')
plt.ylabel('Predictions (MW)')
plt.savefig('graphs/' + model_name + '_comparison.pdf')

# %%
# error histogram
from matplotlib.ticker import PercentFormatter
error = (y_fit - y_test).flatten()
plt.hist(error, bins = 50, weights=np.ones(len(error)) / len(error))
plt.xlabel("Prediction Error (MW)")
_ = plt.ylabel("Percentage")
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.savefig('graphs/' + model_name + '_errordist.pdf')
