# %% [markdown]
# # 0 Modules, path, etc

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import modules
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import data_table

# use data table provided by Colab
data_table.enable_dataframe_formatter()

# %% [markdown]
# Run the following line if the Colab start having trouble navigating directories.

# %%
# reset the path
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# check directory
# !pwd
# Out:
# /content

# %%
# set directory
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# The panel.csv contains:
#
# *   **Labels:** Load (electricity demand in MW) for different weather zones in Texas. The Weather Zones are shown in the figure below.
# *   **Inputs:** Weather data (temperature, dew, humidity, etc) taken from the four largest cities in the state (Dallas, Houston, San Antonio and Austin).

# %%
# inputs
x = pd.read_csv("panel.csv")
x
# Out:
# Warning: total number of rows (61344) exceeds max_rows (20000). Falling back to pandas display.
#          load_coast  cloudcover_houston  dew_houston  feelslike_houston  \
# 0       7607.189871                64.6         19.8               20.0
# 1       7389.267519                65.5         19.3               20.0
# 2       7179.748411               100.0         19.0               19.4
# 3       7039.692524               100.0         18.3               18.5
# 4       6991.412764               100.0         15.9               16.1
# ...             ...                 ...          ...                ...
# 61339  11109.257860                 7.3         -6.6               13.9
# 61340  10846.500060                 6.1         -5.5               13.8
# 61341  10592.539870                 7.3         -5.3               12.9
# 61342  10304.624870                 9.2         -2.5               12.9
# 61343  10019.771130                97.5         -1.6               12.9
#
#        humidity_houston  precip_houston  sealevelpressure_houston  \
# 0                 98.78           0.000                    1013.6
# 1                 95.76           0.014                    1013.6
# 2                 97.31           0.000                    1013.9
# 3                 99.10           1.863                    1013.7
# 4                 99.12           1.546                    1013.6
# ...                 ...             ...                       ...
# 61339             23.66           0.000                    1021.8
# 61340             25.77           0.000                    1022.0
# 61341             27.81           0.000                    1022.0
# 61342             34.29           0.000                    1022.0
# 61343             36.78           0.000                    1022.0
#
#        solarradiation_houston  temp_houston  visibility_houston  \
# 0                         0.0          20.0                 8.6
# 1                         0.0          20.0                 6.0
# 2                         0.0          19.4                 3.5
# 3                         0.0          18.5                 3.1
# 4                         0.0          16.1                 9.5
# ...                       ...           ...                 ...
# 61339                     0.0          13.9                16.0
# 61340                     0.0          13.8                16.0
# 61341                     0.0          12.9                13.3
# 61342                     0.0          12.9                 8.8
# 61343                     0.0          12.9                16.0
#
#        windspeed_houston  hour day_name  weekend  month  year  season  \
# 0                   11.0     0  Tuesday    False      1  2013  winter
# 1                    9.2     1  Tuesday    False      1  2013  winter
# 2                   10.2     2  Tuesday    False      1  2013  winter
# 3                   17.6     3  Tuesday    False      1  2013  winter
# 4                   22.7     4  Tuesday    False      1  2013  winter
# ...                  ...   ...      ...      ...    ...   ...     ...
# 61339                0.0    19  Tuesday    False     12  2019  winter
# 61340                0.8    20  Tuesday    False     12  2019  winter
# 61341                1.0    21  Tuesday    False     12  2019  winter
# 61342                5.6    22  Tuesday    False     12  2019  winter
# 61343                5.4    23  Tuesday    False     12  2019  winter
#
#                       date
# 0      2013-01-01 00:00:00
# 1      2013-01-01 01:00:00
# 2      2013-01-01 02:00:00
# 3      2013-01-01 03:00:00
# 4      2013-01-01 04:00:00
# ...                    ...
# 61339  2019-12-31 19:00:00
# 61340  2019-12-31 20:00:00
# 61341  2019-12-31 21:00:00
# 61342  2019-12-31 22:00:00
# 61343  2019-12-31 23:00:00
#
# [61344 rows x 18 columns]

# %% [markdown]
# Clean the data, normalize it.

# %%
# check for nans
x.isna().sum()
x = x.dropna()

# fix dates
x['date'] = pd.to_datetime(x['date'], infer_datetime_format=True)

# set index
x = x.set_index('date')

# restrict the amount of data used
x = x.loc[(2014 <= x.index.year) & (x.index.year <= 2018)]

# add year as explanatory variable
x['year'] = x.index.year - min(x.index.year)

# sort everything
x = x.sort_values(["date"])

# splits labels and inputs
y = x.filter(like='load')

# take the categorical data off
cat = ['day_name','weekend','month','season']
x_cat = x[cat].astype(str)
x_cat = pd.get_dummies(x_cat)
x = x.drop(cat,axis=1)

# normalize data
x_mean = x.mean()
y_mean = y.mean()
x_std  = x.std()
y_std  = y.std()
x = (x - x_mean) / x_std
y = (y - y_mean) / y_std
# norm_x = (norm_x * x_std) + x_mean

# put the categorical variables back
x = pd.concat([x,x_cat],axis=1)

# choose labels and inputs
y = y[['load_coast']]

# free memory
del cat, x_cat

# %% [markdown]
# Put the data in time series format, use the last "n_past" steps to predict the next "n_future" observations.

# %%
# setting step size
n_past = 96
n_future = 24

# put data in (n_obs x timesteps x n_features)
x_ts = []
y_ts = []
for i in range(n_past, len(x) - (n_future + 1)):
    x_ts.append(x.iloc[(i-n_past):i,0:x.shape[1]])
    y_ts.append(y.iloc[(i):(i+n_future), :])

# transform everything to numpy arrays
x_ts, y_ts = np.array(x_ts), np.array(y_ts)
y_ts = y_ts[:,:,0]

# %% [markdown]
# Split the train and test datasets.

# %%
# train the model using the initial 1000 days
x_train = x_ts[:36000]
y_train = y_ts[:36000]

# validate the model using the final two years
x_test = x_ts[36000:x_ts.shape[0]]
y_test = y_ts[36000:y_ts.shape[0]]

# number of inputs and labels
n_inputs = x.shape[1]
n_labels = y.shape[1]

# %%
# check
print('x_train shape:', x_train.shape)
print('x_train types:', x_train.dtype)
print('y_train types:', y_train.dtype)
# Out:
# x_train shape: (36000, 96, 38)
# x_train types: float64
# y_train types: float64

# %% [markdown]
# # 2 Deep Learning Model

# %% [markdown]
# Set the Tensor Processing Units.

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
tpu_worker = 'grpc://' + os.environ['COLAB_TPU_ADDR']

# get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_worker)

# connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

# set the distribution strategy
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# Import the ingredients used in the model.

# %%
# import things from Keras and TensorFlow
from keras.models    import Sequential
from keras.layers    import Conv1D, LSTM, Dense, Dropout, Flatten
from keras.callbacks import ReduceLROnPlateau
from keras           import backend as K

# %%
#set model for tpu
with strategy.scope():

  model = Sequential([
      # Conv1D(filters=64, kernel_size=2,strides=2, padding="valid", activation="relu", input_shape=(x_train.shape[1],x_train.shape[2])),
      # Conv1D(filters=64, kernel_size=1, strides=1, padding="causal", activation="relu"),
      LSTM(48, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])),
      LSTM(256, return_sequences=False),
      # Flatten(),
      Dense(256, activation = "relu"),
      Dropout(0.1),
      Dense(128, activation="relu"),
      Dense(64, activation="relu"),
      Dropout(0.1),
      Dense(32, activation="relu"),
      # Flatten(),
      Dropout(0.1),
      Dense(n_future)
  ])

  # compile the model
  model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae','mse','mape'])
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.5, beta_1=1e-6)
  reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',factor=0.2, patience=10, mode='auto')

# check if inputs and outputs are coherent
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 96, 48)            16704
#
#  lstm_1 (LSTM)               (None, 256)               312320
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 438,840
# Trainable params: 438,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# model fit
history = model.fit(
    x_train, 
    y_train, 
    validation_split=0.1, 
    verbose=1, 
    epochs=100,
    batch_size = 16,
    shuffle=False,
    validation_data = (x_test, y_test),
    callbacks=[reduce_learning_rate]
    )
# Out:
# Epoch 1/100
# 2250/2250 [==============================] - 54s 21ms/step - loss: 0.2941 - mae: 0.4173 - mse: 0.2941 - mape: 231.0586 - val_loss: 0.9614 - val_mae: 0.7215 - val_mse: 0.9614 - val_mape: 357.3520 - lr: 0.0010
# Epoch 2/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1718 - mae: 0.3187 - mse: 0.1718 - mape: 207.7923 - val_loss: 0.6424 - val_mae: 0.5797 - val_mse: 0.6424 - val_mape: 251.6138 - lr: 0.0010
# Epoch 3/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1493 - mae: 0.2958 - mse: 0.1493 - mape: 196.8662 - val_loss: 0.4911 - val_mae: 0.5076 - val_mse: 0.4911 - val_mape: 250.2691 - lr: 0.0010
# Epoch 4/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.1359 - mae: 0.2821 - mse: 0.1359 - mape: 186.6579 - val_loss: 0.3699 - val_mae: 0.4404 - val_mse: 0.3699 - val_mape: 223.9682 - lr: 0.0010
# Epoch 5/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1270 - mae: 0.2724 - mse: 0.1270 - mape: 177.3506 - val_loss: 0.3498 - val_mae: 0.4298 - val_mse: 0.3498 - val_mape: 222.5974 - lr: 0.0010
# Epoch 6/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.1211 - mae: 0.2657 - mse: 0.1211 - mape: 176.7795 - val_loss: 0.3418 - val_mae: 0.4211 - val_mse: 0.3418 - val_mape: 231.0179 - lr: 0.0010
# Epoch 7/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1161 - mae: 0.2599 - mse: 0.1161 - mape: 167.5866 - val_loss: 0.3235 - val_mae: 0.4078 - val_mse: 0.3235 - val_mape: 242.4291 - lr: 0.0010
# Epoch 8/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1143 - mae: 0.2578 - mse: 0.1143 - mape: 167.0762 - val_loss: 0.3254 - val_mae: 0.4092 - val_mse: 0.3254 - val_mape: 234.9881 - lr: 0.0010
# Epoch 9/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1113 - mae: 0.2538 - mse: 0.1113 - mape: 160.5683 - val_loss: 0.2994 - val_mae: 0.4051 - val_mse: 0.2994 - val_mape: 257.6358 - lr: 0.0010
# Epoch 10/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1064 - mae: 0.2484 - mse: 0.1064 - mape: 158.8336 - val_loss: 0.3122 - val_mae: 0.4275 - val_mse: 0.3122 - val_mape: 288.4901 - lr: 0.0010
# Epoch 11/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1043 - mae: 0.2462 - mse: 0.1043 - mape: 157.1212 - val_loss: 0.2828 - val_mae: 0.3905 - val_mse: 0.2828 - val_mape: 253.9411 - lr: 0.0010
# Epoch 12/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1018 - mae: 0.2428 - mse: 0.1018 - mape: 154.3257 - val_loss: 0.2449 - val_mae: 0.3683 - val_mse: 0.2449 - val_mape: 236.8509 - lr: 0.0010
# Epoch 13/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0988 - mae: 0.2394 - mse: 0.0988 - mape: 152.3898 - val_loss: 0.2369 - val_mae: 0.3575 - val_mse: 0.2369 - val_mape: 233.7185 - lr: 0.0010
# Epoch 14/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0955 - mae: 0.2356 - mse: 0.0955 - mape: 153.4721 - val_loss: 0.2574 - val_mae: 0.3691 - val_mse: 0.2574 - val_mape: 235.7944 - lr: 0.0010
# Epoch 15/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0963 - mae: 0.2364 - mse: 0.0963 - mape: 148.0979 - val_loss: 0.2081 - val_mae: 0.3377 - val_mse: 0.2081 - val_mape: 231.3581 - lr: 0.0010
# Epoch 16/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0977 - mae: 0.2379 - mse: 0.0977 - mape: 152.8270 - val_loss: 0.2067 - val_mae: 0.3327 - val_mse: 0.2067 - val_mape: 225.4011 - lr: 0.0010
# Epoch 17/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0916 - mae: 0.2310 - mse: 0.0916 - mape: 149.1433 - val_loss: 0.2343 - val_mae: 0.3548 - val_mse: 0.2343 - val_mape: 200.3834 - lr: 0.0010
# Epoch 18/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0889 - mae: 0.2284 - mse: 0.0889 - mape: 149.9734 - val_loss: 0.2052 - val_mae: 0.3350 - val_mse: 0.2052 - val_mape: 210.5402 - lr: 0.0010
# Epoch 19/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0877 - mae: 0.2264 - mse: 0.0877 - mape: 148.4053 - val_loss: 0.1990 - val_mae: 0.3282 - val_mse: 0.1990 - val_mape: 219.4272 - lr: 0.0010
# Epoch 20/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0865 - mae: 0.2245 - mse: 0.0865 - mape: 142.9654 - val_loss: 0.1877 - val_mae: 0.3211 - val_mse: 0.1877 - val_mape: 237.7493 - lr: 0.0010
# Epoch 21/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0840 - mae: 0.2211 - mse: 0.0840 - mape: 140.9785 - val_loss: 0.1962 - val_mae: 0.3195 - val_mse: 0.1962 - val_mape: 212.4366 - lr: 0.0010
# Epoch 22/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0834 - mae: 0.2207 - mse: 0.0834 - mape: 141.0412 - val_loss: 0.1950 - val_mae: 0.3236 - val_mse: 0.1950 - val_mape: 193.2555 - lr: 0.0010
# Epoch 23/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0820 - mae: 0.2189 - mse: 0.0820 - mape: 143.4911 - val_loss: 0.1746 - val_mae: 0.3032 - val_mse: 0.1746 - val_mape: 228.9452 - lr: 0.0010
# Epoch 24/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0799 - mae: 0.2156 - mse: 0.0799 - mape: 138.4172 - val_loss: 0.1795 - val_mae: 0.3089 - val_mse: 0.1795 - val_mape: 203.2998 - lr: 0.0010
# Epoch 25/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0768 - mae: 0.2118 - mse: 0.0768 - mape: 132.8308 - val_loss: 0.1882 - val_mae: 0.3156 - val_mse: 0.1882 - val_mape: 214.2697 - lr: 0.0010
# Epoch 26/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0777 - mae: 0.2122 - mse: 0.0777 - mape: 137.0793 - val_loss: 0.2136 - val_mae: 0.3415 - val_mse: 0.2136 - val_mape: 274.2884 - lr: 0.0010
# Epoch 27/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0798 - mae: 0.2139 - mse: 0.0798 - mape: 136.4025 - val_loss: 0.1676 - val_mae: 0.2980 - val_mse: 0.1676 - val_mape: 201.2479 - lr: 0.0010
# Epoch 28/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0728 - mae: 0.2060 - mse: 0.0728 - mape: 133.8779 - val_loss: 0.1816 - val_mae: 0.3061 - val_mse: 0.1816 - val_mape: 230.0011 - lr: 0.0010
# Epoch 29/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0718 - mae: 0.2044 - mse: 0.0718 - mape: 132.8360 - val_loss: 0.1929 - val_mae: 0.3153 - val_mse: 0.1929 - val_mape: 238.3911 - lr: 0.0010
# Epoch 30/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0723 - mae: 0.2053 - mse: 0.0723 - mape: 134.6485 - val_loss: 0.2072 - val_mae: 0.3387 - val_mse: 0.2072 - val_mape: 211.6640 - lr: 0.0010
# Epoch 31/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0730 - mae: 0.2062 - mse: 0.0730 - mape: 130.3912 - val_loss: 0.2605 - val_mae: 0.3659 - val_mse: 0.2605 - val_mape: 254.2569 - lr: 0.0010
# Epoch 32/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0719 - mae: 0.2047 - mse: 0.0719 - mape: 132.2681 - val_loss: 0.2267 - val_mae: 0.3480 - val_mse: 0.2267 - val_mape: 261.8939 - lr: 0.0010
# Epoch 33/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0727 - mae: 0.2057 - mse: 0.0727 - mape: 131.3003 - val_loss: 0.1799 - val_mae: 0.3052 - val_mse: 0.1799 - val_mape: 210.8616 - lr: 0.0010
# Epoch 34/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0724 - mae: 0.2046 - mse: 0.0724 - mape: 135.4236 - val_loss: 0.1688 - val_mae: 0.3037 - val_mse: 0.1688 - val_mape: 197.4156 - lr: 0.0010
# Epoch 35/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0691 - mae: 0.2008 - mse: 0.0691 - mape: 129.7145 - val_loss: 0.2373 - val_mae: 0.3546 - val_mse: 0.2373 - val_mape: 244.0252 - lr: 0.0010
# Epoch 36/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0704 - mae: 0.2019 - mse: 0.0704 - mape: 128.6535 - val_loss: 0.1963 - val_mae: 0.3341 - val_mse: 0.1963 - val_mape: 210.2759 - lr: 0.0010
# Epoch 37/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0672 - mae: 0.1983 - mse: 0.0672 - mape: 131.3046 - val_loss: 0.1650 - val_mae: 0.2992 - val_mse: 0.1650 - val_mape: 210.6889 - lr: 0.0010
# Epoch 38/100
# 2250/2250 [==============================] - 46s 21ms/step - loss: 0.0675 - mae: 0.1985 - mse: 0.0675 - mape: 128.0074 - val_loss: 0.1640 - val_mae: 0.2996 - val_mse: 0.1640 - val_mape: 193.0954 - lr: 0.0010
# Epoch 39/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0654 - mae: 0.1951 - mse: 0.0654 - mape: 124.2054 - val_loss: 0.2282 - val_mae: 0.3533 - val_mse: 0.2282 - val_mape: 258.3947 - lr: 0.0010
# Epoch 40/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0666 - mae: 0.1977 - mse: 0.0666 - mape: 127.6151 - val_loss: 0.1805 - val_mae: 0.3120 - val_mse: 0.1805 - val_mape: 183.9832 - lr: 0.0010
# Epoch 41/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0654 - mae: 0.1956 - mse: 0.0654 - mape: 130.3550 - val_loss: 0.1881 - val_mae: 0.3157 - val_mse: 0.1881 - val_mape: 216.1762 - lr: 0.0010
# Epoch 42/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0644 - mae: 0.1944 - mse: 0.0644 - mape: 124.9198 - val_loss: 0.1566 - val_mae: 0.2865 - val_mse: 0.1566 - val_mape: 198.7361 - lr: 0.0010
# Epoch 43/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0644 - mae: 0.1939 - mse: 0.0644 - mape: 128.2716 - val_loss: 0.1567 - val_mae: 0.2842 - val_mse: 0.1567 - val_mape: 177.6139 - lr: 0.0010
# Epoch 44/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0621 - mae: 0.1914 - mse: 0.0621 - mape: 125.2091 - val_loss: 0.1952 - val_mae: 0.3204 - val_mse: 0.1952 - val_mape: 223.4792 - lr: 0.0010
# Epoch 45/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0626 - mae: 0.1921 - mse: 0.0626 - mape: 125.7143 - val_loss: 0.1422 - val_mae: 0.2709 - val_mse: 0.1422 - val_mape: 180.2637 - lr: 0.0010
# Epoch 46/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0625 - mae: 0.1916 - mse: 0.0625 - mape: 120.7055 - val_loss: 0.1582 - val_mae: 0.2887 - val_mse: 0.1582 - val_mape: 213.7740 - lr: 0.0010
# Epoch 47/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0612 - mae: 0.1895 - mse: 0.0612 - mape: 121.9391 - val_loss: 0.1530 - val_mae: 0.2821 - val_mse: 0.1530 - val_mape: 180.0825 - lr: 0.0010
# Epoch 48/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0623 - mae: 0.1910 - mse: 0.0623 - mape: 121.1192 - val_loss: 0.2002 - val_mae: 0.3228 - val_mse: 0.2002 - val_mape: 217.9737 - lr: 0.0010
# Epoch 49/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0600 - mae: 0.1883 - mse: 0.0600 - mape: 124.1097 - val_loss: 0.1765 - val_mae: 0.3020 - val_mse: 0.1765 - val_mape: 207.6484 - lr: 0.0010
# Epoch 50/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0607 - mae: 0.1885 - mse: 0.0607 - mape: 116.6018 - val_loss: 0.1507 - val_mae: 0.2777 - val_mse: 0.1507 - val_mape: 196.3722 - lr: 0.0010
# Epoch 51/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0602 - mae: 0.1884 - mse: 0.0602 - mape: 121.0015 - val_loss: 0.1557 - val_mae: 0.2838 - val_mse: 0.1557 - val_mape: 190.3045 - lr: 0.0010
# Epoch 52/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0595 - mae: 0.1868 - mse: 0.0595 - mape: 121.8553 - val_loss: 0.1792 - val_mae: 0.3029 - val_mse: 0.1792 - val_mape: 197.6160 - lr: 0.0010
# Epoch 53/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0580 - mae: 0.1851 - mse: 0.0580 - mape: 120.1768 - val_loss: 0.1640 - val_mae: 0.2900 - val_mse: 0.1640 - val_mape: 189.5854 - lr: 0.0010
# Epoch 54/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0574 - mae: 0.1840 - mse: 0.0574 - mape: 117.8696 - val_loss: 0.1490 - val_mae: 0.2769 - val_mse: 0.1490 - val_mape: 193.1000 - lr: 0.0010
# Epoch 55/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0598 - mae: 0.1865 - mse: 0.0598 - mape: 121.9651 - val_loss: 0.1569 - val_mae: 0.2879 - val_mse: 0.1569 - val_mape: 201.6572 - lr: 0.0010
# Epoch 56/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0613 - mae: 0.1896 - mse: 0.0613 - mape: 117.4037 - val_loss: 0.1426 - val_mae: 0.2717 - val_mse: 0.1426 - val_mape: 181.7971 - lr: 2.0000e-04
# Epoch 57/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0551 - mae: 0.1800 - mse: 0.0551 - mape: 113.1851 - val_loss: 0.1368 - val_mae: 0.2639 - val_mse: 0.1368 - val_mape: 170.5830 - lr: 2.0000e-04
# Epoch 58/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0520 - mae: 0.1748 - mse: 0.0520 - mape: 110.3060 - val_loss: 0.1383 - val_mae: 0.2655 - val_mse: 0.1383 - val_mape: 169.3805 - lr: 2.0000e-04
# Epoch 59/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0500 - mae: 0.1710 - mse: 0.0500 - mape: 105.0558 - val_loss: 0.1355 - val_mae: 0.2622 - val_mse: 0.1355 - val_mape: 167.0241 - lr: 2.0000e-04
# Epoch 60/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0486 - mae: 0.1687 - mse: 0.0486 - mape: 105.7391 - val_loss: 0.1323 - val_mae: 0.2576 - val_mse: 0.1323 - val_mape: 161.4938 - lr: 2.0000e-04
# Epoch 61/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0478 - mae: 0.1673 - mse: 0.0478 - mape: 105.0334 - val_loss: 0.1338 - val_mae: 0.2606 - val_mse: 0.1338 - val_mape: 161.9938 - lr: 2.0000e-04
# Epoch 62/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0470 - mae: 0.1658 - mse: 0.0470 - mape: 105.3660 - val_loss: 0.1365 - val_mae: 0.2645 - val_mse: 0.1365 - val_mape: 163.7473 - lr: 2.0000e-04
# Epoch 63/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0464 - mae: 0.1645 - mse: 0.0464 - mape: 106.0080 - val_loss: 0.1329 - val_mae: 0.2597 - val_mse: 0.1329 - val_mape: 160.1944 - lr: 2.0000e-04
# Epoch 64/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0459 - mae: 0.1637 - mse: 0.0459 - mape: 103.6518 - val_loss: 0.1341 - val_mae: 0.2620 - val_mse: 0.1341 - val_mape: 160.6126 - lr: 2.0000e-04
# Epoch 65/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0457 - mae: 0.1633 - mse: 0.0457 - mape: 103.2323 - val_loss: 0.1357 - val_mae: 0.2635 - val_mse: 0.1357 - val_mape: 161.1861 - lr: 2.0000e-04
# Epoch 66/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0456 - mae: 0.1629 - mse: 0.0456 - mape: 103.2103 - val_loss: 0.1291 - val_mae: 0.2562 - val_mse: 0.1291 - val_mape: 155.7386 - lr: 2.0000e-04
# Epoch 67/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0452 - mae: 0.1621 - mse: 0.0452 - mape: 103.0204 - val_loss: 0.1341 - val_mae: 0.2625 - val_mse: 0.1341 - val_mape: 161.5389 - lr: 2.0000e-04
# Epoch 68/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0450 - mae: 0.1618 - mse: 0.0450 - mape: 104.1545 - val_loss: 0.1353 - val_mae: 0.2626 - val_mse: 0.1353 - val_mape: 160.5365 - lr: 2.0000e-04
# Epoch 69/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0444 - mae: 0.1606 - mse: 0.0444 - mape: 102.1844 - val_loss: 0.1372 - val_mae: 0.2672 - val_mse: 0.1372 - val_mape: 157.9227 - lr: 2.0000e-04
# Epoch 70/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0442 - mae: 0.1602 - mse: 0.0442 - mape: 103.9433 - val_loss: 0.1317 - val_mae: 0.2586 - val_mse: 0.1317 - val_mape: 156.7188 - lr: 2.0000e-04
# Epoch 71/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0439 - mae: 0.1595 - mse: 0.0439 - mape: 101.7257 - val_loss: 0.1330 - val_mae: 0.2617 - val_mse: 0.1330 - val_mape: 158.2644 - lr: 2.0000e-04
# Epoch 72/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0437 - mae: 0.1593 - mse: 0.0437 - mape: 99.9044 - val_loss: 0.1369 - val_mae: 0.2661 - val_mse: 0.1369 - val_mape: 162.0563 - lr: 2.0000e-04
# Epoch 73/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0435 - mae: 0.1589 - mse: 0.0435 - mape: 101.4985 - val_loss: 0.1362 - val_mae: 0.2641 - val_mse: 0.1362 - val_mape: 161.3175 - lr: 2.0000e-04
# Epoch 74/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0432 - mae: 0.1583 - mse: 0.0432 - mape: 102.3940 - val_loss: 0.1368 - val_mae: 0.2654 - val_mse: 0.1368 - val_mape: 158.4379 - lr: 2.0000e-04
# Epoch 75/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0432 - mae: 0.1585 - mse: 0.0432 - mape: 100.9306 - val_loss: 0.1359 - val_mae: 0.2638 - val_mse: 0.1359 - val_mape: 160.1236 - lr: 2.0000e-04
# Epoch 76/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0430 - mae: 0.1576 - mse: 0.0430 - mape: 100.7602 - val_loss: 0.1366 - val_mae: 0.2655 - val_mse: 0.1366 - val_mape: 159.7757 - lr: 2.0000e-04
# Epoch 77/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0441 - mae: 0.1600 - mse: 0.0441 - mape: 98.4541 - val_loss: 0.1326 - val_mae: 0.2610 - val_mse: 0.1326 - val_mape: 151.4659 - lr: 4.0000e-05
# Epoch 78/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0431 - mae: 0.1581 - mse: 0.0431 - mape: 100.7579 - val_loss: 0.1330 - val_mae: 0.2611 - val_mse: 0.1330 - val_mape: 150.5879 - lr: 4.0000e-05
# Epoch 79/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0431 - mae: 0.1580 - mse: 0.0431 - mape: 101.5495 - val_loss: 0.1334 - val_mae: 0.2615 - val_mse: 0.1334 - val_mape: 151.9602 - lr: 4.0000e-05
# Epoch 80/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0427 - mae: 0.1572 - mse: 0.0427 - mape: 101.4687 - val_loss: 0.1337 - val_mae: 0.2623 - val_mse: 0.1337 - val_mape: 150.6068 - lr: 4.0000e-05
# Epoch 81/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0427 - mae: 0.1572 - mse: 0.0427 - mape: 100.3359 - val_loss: 0.1336 - val_mae: 0.2619 - val_mse: 0.1336 - val_mape: 151.2977 - lr: 4.0000e-05
# Epoch 82/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0425 - mae: 0.1572 - mse: 0.0425 - mape: 97.8101 - val_loss: 0.1334 - val_mae: 0.2617 - val_mse: 0.1334 - val_mape: 151.1634 - lr: 4.0000e-05
# Epoch 83/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0419 - mae: 0.1558 - mse: 0.0419 - mape: 96.9254 - val_loss: 0.1334 - val_mae: 0.2615 - val_mse: 0.1334 - val_mape: 150.1645 - lr: 4.0000e-05
# Epoch 84/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0417 - mae: 0.1553 - mse: 0.0417 - mape: 99.4259 - val_loss: 0.1346 - val_mae: 0.2638 - val_mse: 0.1346 - val_mape: 151.7372 - lr: 4.0000e-05
# Epoch 85/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0421 - mae: 0.1561 - mse: 0.0421 - mape: 98.3324 - val_loss: 0.1337 - val_mae: 0.2621 - val_mse: 0.1337 - val_mape: 149.9184 - lr: 4.0000e-05
# Epoch 86/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0414 - mae: 0.1551 - mse: 0.0414 - mape: 99.8470 - val_loss: 0.1340 - val_mae: 0.2625 - val_mse: 0.1340 - val_mape: 150.3018 - lr: 4.0000e-05
# Epoch 87/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0427 - mae: 0.1575 - mse: 0.0427 - mape: 101.2661 - val_loss: 0.1288 - val_mae: 0.2553 - val_mse: 0.1288 - val_mape: 147.1042 - lr: 8.0000e-06
# Epoch 88/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0422 - mae: 0.1564 - mse: 0.0422 - mape: 100.7906 - val_loss: 0.1287 - val_mae: 0.2550 - val_mse: 0.1287 - val_mape: 146.8069 - lr: 8.0000e-06
# Epoch 89/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0421 - mae: 0.1562 - mse: 0.0421 - mape: 99.8694 - val_loss: 0.1287 - val_mae: 0.2549 - val_mse: 0.1287 - val_mape: 146.6078 - lr: 8.0000e-06
# Epoch 90/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0423 - mae: 0.1566 - mse: 0.0423 - mape: 99.9059 - val_loss: 0.1285 - val_mae: 0.2543 - val_mse: 0.1285 - val_mape: 146.4813 - lr: 8.0000e-06
# Epoch 91/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0419 - mae: 0.1562 - mse: 0.0419 - mape: 100.1491 - val_loss: 0.1287 - val_mae: 0.2548 - val_mse: 0.1287 - val_mape: 146.4773 - lr: 8.0000e-06
# Epoch 92/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0419 - mae: 0.1558 - mse: 0.0419 - mape: 99.0087 - val_loss: 0.1283 - val_mae: 0.2540 - val_mse: 0.1283 - val_mape: 146.1953 - lr: 8.0000e-06
# Epoch 93/100
# 2250/2250 [==============================] - 46s 20ms/step - loss: 0.0419 - mae: 0.1560 - mse: 0.0419 - mape: 98.2019 - val_loss: 0.1282 - val_mae: 0.2540 - val_mse: 0.1282 - val_mape: 146.2541 - lr: 8.0000e-06
# Epoch 94/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0417 - mae: 0.1555 - mse: 0.0417 - mape: 96.9419 - val_loss: 0.1280 - val_mae: 0.2538 - val_mse: 0.1280 - val_mape: 145.8989 - lr: 8.0000e-06
# Epoch 95/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0423 - mae: 0.1563 - mse: 0.0423 - mape: 98.8702 - val_loss: 0.1281 - val_mae: 0.2536 - val_mse: 0.1281 - val_mape: 145.8136 - lr: 8.0000e-06
# Epoch 96/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0421 - mae: 0.1560 - mse: 0.0421 - mape: 99.2511 - val_loss: 0.1280 - val_mae: 0.2535 - val_mse: 0.1280 - val_mape: 145.8375 - lr: 8.0000e-06
# Epoch 97/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0420 - mae: 0.1558 - mse: 0.0420 - mape: 97.5273 - val_loss: 0.1279 - val_mae: 0.2532 - val_mse: 0.1279 - val_mape: 145.7234 - lr: 8.0000e-06
# Epoch 98/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0421 - mae: 0.1561 - mse: 0.0421 - mape: 97.2731 - val_loss: 0.1280 - val_mae: 0.2534 - val_mse: 0.1280 - val_mape: 145.7773 - lr: 8.0000e-06
# Epoch 99/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0417 - mae: 0.1555 - mse: 0.0417 - mape: 98.7186 - val_loss: 0.1279 - val_mae: 0.2536 - val_mse: 0.1279 - val_mape: 145.6886 - lr: 8.0000e-06
# Epoch 100/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.0414 - mae: 0.1551 - mse: 0.0414 - mape: 99.7653 - val_loss: 0.1279 - val_mae: 0.2534 - val_mse: 0.1279 - val_mape: 145.7122 - lr: 8.0000e-06
# CPU times: user 30min 3s, sys: 8min 52s, total: 38min 55s
# Wall time: 1h 15min 23s

# %% [markdown]
# Save the model weights.

# %%
# save model
model.save_weights('lstm.h5', overwrite=True)

# %% [markdown]
# # 3 Error Analysis.

# %% [markdown]
# Run this cell if loading weights.

# %%
# model.load_weights('lstm.h5')

# %% [markdown]
# Forecasting and model evaluation

# %%
# model predictions
y_fit = model.predict(x_test)

# evaluate the model using test data
model.evaluate(x_test, y_test)
# Out:
# 241/241 [==============================] - 5s 14ms/step
# 241/241 [==============================] - 6s 20ms/step - loss: 0.1319 - mae: 0.2578 - mse: 0.1319 - mape: 139.3996
# [0.13191692531108856,
#  0.2578417956829071,
#  0.13191692531108856,
#  139.39964294433594]

# %% [markdown]
# Descale the forecasted values.

# %%
# descale the predictions
y_fit = (y_fit * y_std[0]) + y_mean[0]
y_test = (y_test * y_std[0]) + y_mean[0]

# %% [markdown]
# These are the dates where the forecasting starts.
#
# For example, "2016-10-01 02:00:00" means that the first forecasted hour is 2 AM of date 2016-10-01.

# %%
# first forecasted datetime
y_dates = []
for i in range(n_past, len(x) - (n_future + 1)):
    y_dates.append(y.index[i])

# %%
# put results in a dataframe
results = pd.DataFrame(index=y_dates)
results.index.name = 'datetime'
results = results[36000:x_ts.shape[0]]

# %%
# drop results and actual values for all forecasted hours
for h in range(0,y_fit.shape[1]):
  results['fit_' + str(h)] = y_fit[:,h]
  results['actual_' + str(h)] = y_test[:,h]

# %%
results.to_csv('lstm_results.csv')

# %% [markdown]
# # 4 Error Graphs

# %%
# plot
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.savefig('lstm_training.pdf')

# %%
# plot
plt.figure(figsize=(30,5))
plt.plot(y_test[0:1500,0], label='Actual')
plt.plot(y_fit[0:1500,0], label='Forecast')
plt.xlabel('Hour')
plt.ylabel('Load (MW)')
plt.legend()
plt.grid(True)
plt.savefig('lstm_fit.pdf')

# %%
# comparison between predicted and actual values
plt.figure(figsize=(20,10))
a = plt.axes(aspect='equal')
plt.scatter(y_test[:], y_fit[:])
b = np.linspace(*a.get_xlim())
a.plot(b, b, color='black')
plt.xlabel('True Value (MW)')
plt.ylabel('Predictions (MW)')
plt.savefig('lstm_comparison.pdf')

# %%
# error histogram
from matplotlib.ticker import PercentFormatter
error = (y_fit - y_test).flatten()
plt.hist(error, bins = 50, weights=np.ones(len(error)) / len(error))
plt.xlabel("Prediction Error (MW)")
_ = plt.ylabel("Percentage")
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.savefig('lstm_errordist.pdf')
