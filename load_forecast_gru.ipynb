# %% [markdown]
# # 0 Modules, path, etc

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import modules
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import data_table

# use data table provided by Colab
data_table.enable_dataframe_formatter()

# %% [markdown]
# Run the following line if the Colab start having trouble navigating directories.

# %%
# reset the path
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# check directory
# !pwd
# Out:
# /content

# %%
# set directory
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# The panel.csv contains:
#
# *   **Labels:** Load (electricity demand in MW) for different weather zones in Texas. The Weather Zones are shown in the figure below.
# *   **Inputs:** Weather data (temperature, dew, humidity, etc) taken from the four largest cities in the state (Dallas, Houston, San Antonio and Austin).

# %%
# inputs
x = pd.read_csv("panel.csv")
x
# Out:
# Warning: total number of rows (61344) exceeds max_rows (20000). Falling back to pandas display.
#          load_coast  cloudcover_houston  dew_houston  feelslike_houston  \
# 0       7607.189871                64.6         19.8               20.0
# 1       7389.267519                65.5         19.3               20.0
# 2       7179.748411               100.0         19.0               19.4
# 3       7039.692524               100.0         18.3               18.5
# 4       6991.412764               100.0         15.9               16.1
# ...             ...                 ...          ...                ...
# 61339  11109.257860                 7.3         -6.6               13.9
# 61340  10846.500060                 6.1         -5.5               13.8
# 61341  10592.539870                 7.3         -5.3               12.9
# 61342  10304.624870                 9.2         -2.5               12.9
# 61343  10019.771130                97.5         -1.6               12.9
#
#        humidity_houston  precip_houston  sealevelpressure_houston  \
# 0                 98.78           0.000                    1013.6
# 1                 95.76           0.014                    1013.6
# 2                 97.31           0.000                    1013.9
# 3                 99.10           1.863                    1013.7
# 4                 99.12           1.546                    1013.6
# ...                 ...             ...                       ...
# 61339             23.66           0.000                    1021.8
# 61340             25.77           0.000                    1022.0
# 61341             27.81           0.000                    1022.0
# 61342             34.29           0.000                    1022.0
# 61343             36.78           0.000                    1022.0
#
#        solarradiation_houston  temp_houston  visibility_houston  \
# 0                         0.0          20.0                 8.6
# 1                         0.0          20.0                 6.0
# 2                         0.0          19.4                 3.5
# 3                         0.0          18.5                 3.1
# 4                         0.0          16.1                 9.5
# ...                       ...           ...                 ...
# 61339                     0.0          13.9                16.0
# 61340                     0.0          13.8                16.0
# 61341                     0.0          12.9                13.3
# 61342                     0.0          12.9                 8.8
# 61343                     0.0          12.9                16.0
#
#        windspeed_houston  hour day_name  weekend  month  year  season  \
# 0                   11.0     0  Tuesday    False      1  2013  winter
# 1                    9.2     1  Tuesday    False      1  2013  winter
# 2                   10.2     2  Tuesday    False      1  2013  winter
# 3                   17.6     3  Tuesday    False      1  2013  winter
# 4                   22.7     4  Tuesday    False      1  2013  winter
# ...                  ...   ...      ...      ...    ...   ...     ...
# 61339                0.0    19  Tuesday    False     12  2019  winter
# 61340                0.8    20  Tuesday    False     12  2019  winter
# 61341                1.0    21  Tuesday    False     12  2019  winter
# 61342                5.6    22  Tuesday    False     12  2019  winter
# 61343                5.4    23  Tuesday    False     12  2019  winter
#
#                       date
# 0      2013-01-01 00:00:00
# 1      2013-01-01 01:00:00
# 2      2013-01-01 02:00:00
# 3      2013-01-01 03:00:00
# 4      2013-01-01 04:00:00
# ...                    ...
# 61339  2019-12-31 19:00:00
# 61340  2019-12-31 20:00:00
# 61341  2019-12-31 21:00:00
# 61342  2019-12-31 22:00:00
# 61343  2019-12-31 23:00:00
#
# [61344 rows x 18 columns]

# %% [markdown]
# Clean the data, normalize it.

# %%
# check for nans
x.isna().sum()
x = x.dropna()

# fix dates
x['date'] = pd.to_datetime(x['date'], infer_datetime_format=True)

# set index
x = x.set_index('date')

# restrict the amount of data used
x = x.loc[(2014 <= x.index.year) & (x.index.year <= 2018)]

# add year as explanatory variable
x['year'] = x.index.year - min(x.index.year)

# sort everything
x = x.sort_values(["date"])

# splits labels and inputs
y = x.filter(like='load')

# take the categorical data off
cat = ['day_name','weekend','month','season']
x_cat = x[cat].astype(str)
x_cat = pd.get_dummies(x_cat)
x = x.drop(cat,axis=1)

# normalize data
x_mean = x.mean()
y_mean = y.mean()
x_std  = x.std()
y_std  = y.std()
x = (x - x_mean) / x_std
y = (y - y_mean) / y_std
# norm_x = (norm_x * x_std) + x_mean

# put the categorical variables back
x = pd.concat([x,x_cat],axis=1)

# choose labels and inputs
y = y[['load_coast']]

# free memory
del cat, x_cat

# %% [markdown]
# Put the data in time series format, use the last "n_past" steps to predict the next "n_future" observations.

# %%
# setting step size
n_past = 96
n_future = 24

# put data in (n_obs x timesteps x n_features)
x_ts = []
y_ts = []
for i in range(n_past, len(x) - (n_future + 1)):
    x_ts.append(x.iloc[(i-n_past):i,0:x.shape[1]])
    y_ts.append(y.iloc[(i):(i+n_future), :])

# transform everything to numpy arrays
x_ts, y_ts = np.array(x_ts), np.array(y_ts)
y_ts = y_ts[:,:,0]

# %% [markdown]
# Split the train and test datasets.

# %%
# train the model using the initial 1000 days
x_train = x_ts[:36000]
y_train = y_ts[:36000]

# validate the model using the final two years
x_test = x_ts[36000:x_ts.shape[0]]
y_test = y_ts[36000:y_ts.shape[0]]

# number of inputs and labels
n_inputs = x.shape[1]
n_labels = y.shape[1]

# %%
# check
print('x_train shape:', x_train.shape)
print('x_train types:', x_train.dtype)
print('y_train types:', y_train.dtype)
# Out:
# x_train shape: (36000, 96, 38)
# x_train types: float64
# y_train types: float64

# %% [markdown]
# # 2 Deep Learning Model

# %% [markdown]
# Set the Tensor Processing Units.

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
tpu_worker = 'grpc://' + os.environ['COLAB_TPU_ADDR']

# get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_worker)

# connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

# set the distribution strategy
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# Import the ingredients used in the model.

# %%
# import things from Keras and TensorFlow
from keras.models    import Sequential
from keras.layers    import Conv1D, GRU, Dense, Dropout, Flatten
from keras.callbacks import ReduceLROnPlateau
from keras           import backend as K

# %%
#set model for tpu
with strategy.scope():

  model = Sequential([
      # Conv1D(filters=64, kernel_size=2,strides=2, padding="valid", activation="relu", input_shape=(x_train.shape[1],x_train.shape[2])),
      # Conv1D(filters=64, kernel_size=1, strides=1, padding="causal", activation="relu"),
      GRU(48, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])),
      GRU(256, return_sequences=False),
      # Flatten(),
      Dense(256, activation = "relu"),
      Dropout(0.1),
      Dense(128, activation="relu"),
      Dense(64, activation="relu"),
      Dropout(0.1),
      Dense(32, activation="relu"),
      # Flatten(),
      Dropout(0.1),
      Dense(n_future)
  ])

  # compile the model
  model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae','mse','mape'])
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.5, beta_1=1e-6)
  reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',factor=0.2, patience=10, mode='auto')

# check if inputs and outputs are coherent
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 96, 48)            12672
#
#  gru_1 (GRU)                 (None, 256)               235008
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 357,496
# Trainable params: 357,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# model fit
history = model.fit(
    x_train, 
    y_train, 
    validation_split=0.1, 
    verbose=1, 
    epochs=100,
    batch_size = 16,
    shuffle=False,
    validation_data = (x_test, y_test),
    callbacks=[reduce_learning_rate]
    )
# Out:
# Epoch 1/100
# 2250/2250 [==============================] - 53s 21ms/step - loss: 0.2528 - mae: 0.3885 - mse: 0.2528 - mape: 216.6192 - val_loss: 1.1945 - val_mae: 0.7965 - val_mse: 1.1945 - val_mape: 354.4308 - lr: 0.0010
# Epoch 2/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1706 - mae: 0.3181 - mse: 0.1706 - mape: 198.7309 - val_loss: 0.7244 - val_mae: 0.6250 - val_mse: 0.7244 - val_mape: 271.3357 - lr: 0.0010
# Epoch 3/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.1502 - mae: 0.2976 - mse: 0.1502 - mape: 186.8354 - val_loss: 0.5483 - val_mae: 0.5399 - val_mse: 0.5483 - val_mape: 230.2752 - lr: 0.0010
# Epoch 4/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1356 - mae: 0.2823 - mse: 0.1356 - mape: 182.1445 - val_loss: 0.4880 - val_mae: 0.4987 - val_mse: 0.4880 - val_mape: 207.1002 - lr: 0.0010
# Epoch 5/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1299 - mae: 0.2754 - mse: 0.1299 - mape: 178.6299 - val_loss: 0.3415 - val_mae: 0.4340 - val_mse: 0.3415 - val_mape: 185.0940 - lr: 0.0010
# Epoch 6/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1251 - mae: 0.2697 - mse: 0.1251 - mape: 172.8123 - val_loss: 0.3403 - val_mae: 0.4211 - val_mse: 0.3403 - val_mape: 218.6809 - lr: 0.0010
# Epoch 7/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1186 - mae: 0.2623 - mse: 0.1186 - mape: 170.5449 - val_loss: 0.3006 - val_mae: 0.3976 - val_mse: 0.3006 - val_mape: 218.4286 - lr: 0.0010
# Epoch 8/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.1174 - mae: 0.2609 - mse: 0.1174 - mape: 166.6944 - val_loss: 0.3376 - val_mae: 0.4191 - val_mse: 0.3376 - val_mape: 208.9660 - lr: 0.0010
# Epoch 9/100
# 2250/2250 [==============================] - 45s 20ms/step - loss: 0.1140 - mae: 0.2568 - mse: 0.1140 - mape: 164.2079 - val_loss: 0.3657 - val_mae: 0.4273 - val_mse: 0.3657 - val_mape: 221.4353 - lr: 0.0010
# Epoch 10/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.1119 - mae: 0.2540 - mse: 0.1119 - mape: 160.4895 - val_loss: 0.2948 - val_mae: 0.3961 - val_mse: 0.2948 - val_mape: 200.6069 - lr: 0.0010
# Epoch 11/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.1104 - mae: 0.2525 - mse: 0.1104 - mape: 165.3205 - val_loss: 0.4669 - val_mae: 0.4859 - val_mse: 0.4669 - val_mape: 260.6054 - lr: 0.0010
# Epoch 12/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.1052 - mae: 0.2467 - mse: 0.1052 - mape: 159.3514 - val_loss: 0.3141 - val_mae: 0.4162 - val_mse: 0.3141 - val_mape: 226.3772 - lr: 0.0010
# Epoch 13/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.1022 - mae: 0.2428 - mse: 0.1022 - mape: 159.4959 - val_loss: 0.5873 - val_mae: 0.5363 - val_mse: 0.5873 - val_mape: 254.5187 - lr: 0.0010
# Epoch 14/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0993 - mae: 0.2399 - mse: 0.0993 - mape: 151.0074 - val_loss: 0.3736 - val_mae: 0.4432 - val_mse: 0.3736 - val_mape: 239.0877 - lr: 0.0010
# Epoch 15/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0983 - mae: 0.2392 - mse: 0.0983 - mape: 155.1929 - val_loss: 0.3261 - val_mae: 0.4310 - val_mse: 0.3261 - val_mape: 236.4225 - lr: 0.0010
# Epoch 16/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0926 - mae: 0.2316 - mse: 0.0926 - mape: 151.2668 - val_loss: 0.2478 - val_mae: 0.3838 - val_mse: 0.2478 - val_mape: 234.5021 - lr: 0.0010
# Epoch 17/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0928 - mae: 0.2323 - mse: 0.0928 - mape: 150.5650 - val_loss: 0.3272 - val_mae: 0.4393 - val_mse: 0.3272 - val_mape: 265.0901 - lr: 0.0010
# Epoch 18/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0888 - mae: 0.2279 - mse: 0.0888 - mape: 149.9436 - val_loss: 0.3263 - val_mae: 0.4315 - val_mse: 0.3263 - val_mape: 234.7659 - lr: 0.0010
# Epoch 19/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0888 - mae: 0.2276 - mse: 0.0888 - mape: 149.1013 - val_loss: 0.2391 - val_mae: 0.3588 - val_mse: 0.2391 - val_mape: 187.2779 - lr: 0.0010
# Epoch 20/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0850 - mae: 0.2235 - mse: 0.0850 - mape: 145.6551 - val_loss: 0.2423 - val_mae: 0.3542 - val_mse: 0.2423 - val_mape: 184.2709 - lr: 0.0010
# Epoch 21/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0851 - mae: 0.2228 - mse: 0.0851 - mape: 141.1088 - val_loss: 0.2091 - val_mae: 0.3336 - val_mse: 0.2091 - val_mape: 206.6165 - lr: 0.0010
# Epoch 22/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0850 - mae: 0.2240 - mse: 0.0850 - mape: 143.3927 - val_loss: 0.2051 - val_mae: 0.3312 - val_mse: 0.2051 - val_mape: 180.8146 - lr: 0.0010
# Epoch 23/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0810 - mae: 0.2181 - mse: 0.0810 - mape: 141.1812 - val_loss: 0.2402 - val_mae: 0.3448 - val_mse: 0.2402 - val_mape: 167.6955 - lr: 0.0010
# Epoch 24/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0824 - mae: 0.2202 - mse: 0.0824 - mape: 143.5858 - val_loss: 0.1953 - val_mae: 0.3095 - val_mse: 0.1953 - val_mape: 165.9986 - lr: 0.0010
# Epoch 25/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0835 - mae: 0.2212 - mse: 0.0835 - mape: 139.9710 - val_loss: 0.2152 - val_mae: 0.3412 - val_mse: 0.2152 - val_mape: 164.3874 - lr: 0.0010
# Epoch 26/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0824 - mae: 0.2193 - mse: 0.0824 - mape: 139.1029 - val_loss: 0.2152 - val_mae: 0.3304 - val_mse: 0.2152 - val_mape: 181.1420 - lr: 0.0010
# Epoch 27/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0814 - mae: 0.2186 - mse: 0.0814 - mape: 143.6854 - val_loss: 0.2904 - val_mae: 0.3628 - val_mse: 0.2904 - val_mape: 178.0555 - lr: 0.0010
# Epoch 28/100
# 2250/2250 [==============================] - 42s 18ms/step - loss: 0.0822 - mae: 0.2197 - mse: 0.0822 - mape: 141.1876 - val_loss: 0.1869 - val_mae: 0.3204 - val_mse: 0.1869 - val_mape: 186.9274 - lr: 0.0010
# Epoch 29/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0772 - mae: 0.2133 - mse: 0.0772 - mape: 137.6500 - val_loss: 0.1903 - val_mae: 0.3112 - val_mse: 0.1903 - val_mape: 159.4708 - lr: 0.0010
# Epoch 30/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0783 - mae: 0.2147 - mse: 0.0783 - mape: 140.1019 - val_loss: 0.2310 - val_mae: 0.3352 - val_mse: 0.2310 - val_mape: 169.2693 - lr: 0.0010
# Epoch 31/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0752 - mae: 0.2108 - mse: 0.0752 - mape: 135.6603 - val_loss: 0.1672 - val_mae: 0.2947 - val_mse: 0.1672 - val_mape: 184.1411 - lr: 0.0010
# Epoch 32/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0779 - mae: 0.2141 - mse: 0.0779 - mape: 140.0301 - val_loss: 0.2367 - val_mae: 0.3473 - val_mse: 0.2367 - val_mape: 176.3075 - lr: 0.0010
# Epoch 33/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0746 - mae: 0.2099 - mse: 0.0746 - mape: 139.9877 - val_loss: 0.1596 - val_mae: 0.2858 - val_mse: 0.1596 - val_mape: 173.1159 - lr: 0.0010
# Epoch 34/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0773 - mae: 0.2135 - mse: 0.0773 - mape: 138.3629 - val_loss: 0.2052 - val_mae: 0.3470 - val_mse: 0.2052 - val_mape: 152.5151 - lr: 0.0010
# Epoch 35/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0791 - mae: 0.2154 - mse: 0.0791 - mape: 139.6766 - val_loss: 0.1837 - val_mae: 0.3044 - val_mse: 0.1837 - val_mape: 180.0277 - lr: 0.0010
# Epoch 36/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0775 - mae: 0.2136 - mse: 0.0775 - mape: 143.5079 - val_loss: 0.1771 - val_mae: 0.3074 - val_mse: 0.1771 - val_mape: 180.2812 - lr: 0.0010
# Epoch 37/100
# 2250/2250 [==============================] - 39s 17ms/step - loss: 0.0738 - mae: 0.2085 - mse: 0.0738 - mape: 138.6284 - val_loss: 0.1577 - val_mae: 0.2940 - val_mse: 0.1577 - val_mape: 178.5550 - lr: 0.0010
# Epoch 38/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0764 - mae: 0.2126 - mse: 0.0764 - mape: 137.7871 - val_loss: 0.1547 - val_mae: 0.2857 - val_mse: 0.1547 - val_mape: 165.4439 - lr: 0.0010
# Epoch 39/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0741 - mae: 0.2097 - mse: 0.0741 - mape: 135.3758 - val_loss: 0.1630 - val_mae: 0.2848 - val_mse: 0.1630 - val_mape: 180.5812 - lr: 0.0010
# Epoch 40/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0739 - mae: 0.2092 - mse: 0.0739 - mape: 135.0370 - val_loss: 0.1623 - val_mae: 0.2893 - val_mse: 0.1623 - val_mape: 175.2452 - lr: 0.0010
# Epoch 41/100
# 2250/2250 [==============================] - 39s 17ms/step - loss: 0.0737 - mae: 0.2085 - mse: 0.0737 - mape: 133.5095 - val_loss: 0.1533 - val_mae: 0.2871 - val_mse: 0.1533 - val_mape: 167.7533 - lr: 0.0010
# Epoch 42/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0729 - mae: 0.2069 - mse: 0.0729 - mape: 137.2763 - val_loss: 0.2001 - val_mae: 0.3315 - val_mse: 0.2001 - val_mape: 214.3208 - lr: 0.0010
# Epoch 43/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0736 - mae: 0.2085 - mse: 0.0736 - mape: 139.1992 - val_loss: 0.2051 - val_mae: 0.3344 - val_mse: 0.2051 - val_mape: 170.3682 - lr: 0.0010
# Epoch 44/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0737 - mae: 0.2082 - mse: 0.0737 - mape: 131.0586 - val_loss: 0.1721 - val_mae: 0.2989 - val_mse: 0.1721 - val_mape: 210.7283 - lr: 0.0010
# Epoch 45/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0770 - mae: 0.2128 - mse: 0.0770 - mape: 137.1043 - val_loss: 0.1673 - val_mae: 0.2968 - val_mse: 0.1673 - val_mape: 191.6368 - lr: 0.0010
# Epoch 46/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0715 - mae: 0.2058 - mse: 0.0715 - mape: 133.2199 - val_loss: 0.1799 - val_mae: 0.3122 - val_mse: 0.1799 - val_mape: 164.3008 - lr: 0.0010
# Epoch 47/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0715 - mae: 0.2053 - mse: 0.0715 - mape: 136.2275 - val_loss: 0.1863 - val_mae: 0.3123 - val_mse: 0.1863 - val_mape: 188.2320 - lr: 0.0010
# Epoch 48/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0721 - mae: 0.2060 - mse: 0.0721 - mape: 134.1707 - val_loss: 0.1575 - val_mae: 0.2828 - val_mse: 0.1575 - val_mape: 176.4235 - lr: 0.0010
# Epoch 49/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0706 - mae: 0.2040 - mse: 0.0706 - mape: 132.0212 - val_loss: 0.1803 - val_mae: 0.3218 - val_mse: 0.1803 - val_mape: 160.7189 - lr: 0.0010
# Epoch 50/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0698 - mae: 0.2026 - mse: 0.0698 - mape: 131.3117 - val_loss: 0.1791 - val_mae: 0.3063 - val_mse: 0.1791 - val_mape: 177.3775 - lr: 0.0010
# Epoch 51/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0748 - mae: 0.2103 - mse: 0.0748 - mape: 133.9053 - val_loss: 0.1948 - val_mae: 0.3231 - val_mse: 0.1948 - val_mape: 194.9339 - lr: 0.0010
# Epoch 52/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0780 - mae: 0.2127 - mse: 0.0780 - mape: 141.3836 - val_loss: 0.1409 - val_mae: 0.2706 - val_mse: 0.1409 - val_mape: 143.7338 - lr: 2.0000e-04
# Epoch 53/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0657 - mae: 0.1970 - mse: 0.0657 - mape: 132.1803 - val_loss: 0.1429 - val_mae: 0.2700 - val_mse: 0.1429 - val_mape: 153.5051 - lr: 2.0000e-04
# Epoch 54/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0605 - mae: 0.1892 - mse: 0.0605 - mape: 125.8061 - val_loss: 0.1404 - val_mae: 0.2673 - val_mse: 0.1404 - val_mape: 146.4397 - lr: 2.0000e-04
# Epoch 55/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0580 - mae: 0.1851 - mse: 0.0580 - mape: 120.2937 - val_loss: 0.1389 - val_mae: 0.2635 - val_mse: 0.1389 - val_mape: 145.2233 - lr: 2.0000e-04
# Epoch 56/100
# 2250/2250 [==============================] - 42s 19ms/step - loss: 0.0565 - mae: 0.1825 - mse: 0.0565 - mape: 117.6278 - val_loss: 0.1398 - val_mae: 0.2614 - val_mse: 0.1398 - val_mape: 139.1134 - lr: 2.0000e-04
# Epoch 57/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0544 - mae: 0.1788 - mse: 0.0544 - mape: 115.0676 - val_loss: 0.1363 - val_mae: 0.2581 - val_mse: 0.1363 - val_mape: 142.3813 - lr: 2.0000e-04
# Epoch 58/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0533 - mae: 0.1768 - mse: 0.0533 - mape: 114.1864 - val_loss: 0.1327 - val_mae: 0.2554 - val_mse: 0.1327 - val_mape: 139.1196 - lr: 2.0000e-04
# Epoch 59/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0526 - mae: 0.1757 - mse: 0.0526 - mape: 115.3019 - val_loss: 0.1352 - val_mae: 0.2581 - val_mse: 0.1352 - val_mape: 136.9633 - lr: 2.0000e-04
# Epoch 60/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0517 - mae: 0.1742 - mse: 0.0517 - mape: 113.4348 - val_loss: 0.1357 - val_mae: 0.2579 - val_mse: 0.1357 - val_mape: 147.0175 - lr: 2.0000e-04
# Epoch 61/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0509 - mae: 0.1728 - mse: 0.0509 - mape: 115.7988 - val_loss: 0.1339 - val_mae: 0.2562 - val_mse: 0.1339 - val_mape: 136.6024 - lr: 2.0000e-04
# Epoch 62/100
# 2250/2250 [==============================] - 41s 18ms/step - loss: 0.0502 - mae: 0.1713 - mse: 0.0502 - mape: 109.3393 - val_loss: 0.1392 - val_mae: 0.2595 - val_mse: 0.1392 - val_mape: 139.1973 - lr: 2.0000e-04
# Epoch 63/100
# 2250/2250 [==============================] - 42s 18ms/step - loss: 0.0493 - mae: 0.1698 - mse: 0.0493 - mape: 110.6143 - val_loss: 0.1361 - val_mae: 0.2584 - val_mse: 0.1361 - val_mape: 144.1252 - lr: 2.0000e-04
# Epoch 64/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0493 - mae: 0.1697 - mse: 0.0493 - mape: 108.8222 - val_loss: 0.1390 - val_mae: 0.2613 - val_mse: 0.1390 - val_mape: 142.0582 - lr: 2.0000e-04
# Epoch 65/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0488 - mae: 0.1688 - mse: 0.0488 - mape: 110.3710 - val_loss: 0.1366 - val_mae: 0.2570 - val_mse: 0.1366 - val_mape: 138.4841 - lr: 2.0000e-04
# Epoch 66/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0486 - mae: 0.1683 - mse: 0.0486 - mape: 108.1043 - val_loss: 0.1399 - val_mae: 0.2629 - val_mse: 0.1399 - val_mape: 142.7655 - lr: 2.0000e-04
# Epoch 67/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0480 - mae: 0.1675 - mse: 0.0480 - mape: 106.9963 - val_loss: 0.1401 - val_mae: 0.2630 - val_mse: 0.1401 - val_mape: 139.9926 - lr: 2.0000e-04
# Epoch 68/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0476 - mae: 0.1665 - mse: 0.0476 - mape: 105.7347 - val_loss: 0.1379 - val_mae: 0.2584 - val_mse: 0.1379 - val_mape: 141.9192 - lr: 2.0000e-04
# Epoch 69/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0484 - mae: 0.1683 - mse: 0.0484 - mape: 107.1532 - val_loss: 0.1384 - val_mae: 0.2587 - val_mse: 0.1384 - val_mape: 136.8590 - lr: 4.0000e-05
# Epoch 70/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0474 - mae: 0.1662 - mse: 0.0474 - mape: 105.8563 - val_loss: 0.1400 - val_mae: 0.2601 - val_mse: 0.1400 - val_mape: 136.3139 - lr: 4.0000e-05
# Epoch 71/100
# 2250/2250 [==============================] - 40s 18ms/step - loss: 0.0470 - mae: 0.1653 - mse: 0.0470 - mape: 105.3272 - val_loss: 0.1388 - val_mae: 0.2583 - val_mse: 0.1388 - val_mape: 136.0627 - lr: 4.0000e-05
# Epoch 72/100
# 2250/2250 [==============================] - 39s 17ms/step - loss: 0.0461 - mae: 0.1639 - mse: 0.0461 - mape: 103.3424 - val_loss: 0.1397 - val_mae: 0.2598 - val_mse: 0.1397 - val_mape: 135.1497 - lr: 4.0000e-05
# Epoch 73/100
# 2250/2250 [==============================] - 39s 17ms/step - loss: 0.0460 - mae: 0.1634 - mse: 0.0460 - mape: 102.6625 - val_loss: 0.1390 - val_mae: 0.2587 - val_mse: 0.1390 - val_mape: 135.3377 - lr: 4.0000e-05
# Epoch 74/100
# 2250/2250 [==============================] - 39s 17ms/step - loss: 0.0456 - mae: 0.1630 - mse: 0.0456 - mape: 102.5941 - val_loss: 0.1393 - val_mae: 0.2582 - val_mse: 0.1393 - val_mape: 136.0770 - lr: 4.0000e-05
# Epoch 75/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0456 - mae: 0.1628 - mse: 0.0456 - mape: 103.3700 - val_loss: 0.1389 - val_mae: 0.2583 - val_mse: 0.1389 - val_mape: 135.1528 - lr: 4.0000e-05
# Epoch 76/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0460 - mae: 0.1633 - mse: 0.0460 - mape: 101.5154 - val_loss: 0.1391 - val_mae: 0.2583 - val_mse: 0.1391 - val_mape: 135.9268 - lr: 4.0000e-05
# Epoch 77/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0453 - mae: 0.1621 - mse: 0.0453 - mape: 103.0574 - val_loss: 0.1400 - val_mae: 0.2599 - val_mse: 0.1400 - val_mape: 136.2551 - lr: 4.0000e-05
# Epoch 78/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0450 - mae: 0.1615 - mse: 0.0450 - mape: 103.4672 - val_loss: 0.1397 - val_mae: 0.2595 - val_mse: 0.1397 - val_mape: 135.8599 - lr: 4.0000e-05
# Epoch 79/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0462 - mae: 0.1641 - mse: 0.0462 - mape: 102.6392 - val_loss: 0.1388 - val_mae: 0.2583 - val_mse: 0.1388 - val_mape: 136.9261 - lr: 8.0000e-06
# Epoch 80/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0456 - mae: 0.1627 - mse: 0.0456 - mape: 103.8498 - val_loss: 0.1390 - val_mae: 0.2586 - val_mse: 0.1390 - val_mape: 136.8281 - lr: 8.0000e-06
# Epoch 81/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0455 - mae: 0.1625 - mse: 0.0455 - mape: 102.4300 - val_loss: 0.1391 - val_mae: 0.2586 - val_mse: 0.1391 - val_mape: 136.6454 - lr: 8.0000e-06
# Epoch 82/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0454 - mae: 0.1621 - mse: 0.0454 - mape: 102.6529 - val_loss: 0.1392 - val_mae: 0.2586 - val_mse: 0.1392 - val_mape: 136.6792 - lr: 8.0000e-06
# Epoch 83/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0452 - mae: 0.1621 - mse: 0.0452 - mape: 103.1989 - val_loss: 0.1392 - val_mae: 0.2588 - val_mse: 0.1392 - val_mape: 136.4729 - lr: 8.0000e-06
# Epoch 84/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0450 - mae: 0.1617 - mse: 0.0450 - mape: 103.7548 - val_loss: 0.1394 - val_mae: 0.2591 - val_mse: 0.1394 - val_mape: 136.2868 - lr: 8.0000e-06
# Epoch 85/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0453 - mae: 0.1621 - mse: 0.0453 - mape: 102.9567 - val_loss: 0.1396 - val_mae: 0.2590 - val_mse: 0.1396 - val_mape: 136.5117 - lr: 8.0000e-06
# Epoch 86/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0455 - mae: 0.1622 - mse: 0.0455 - mape: 102.6216 - val_loss: 0.1396 - val_mae: 0.2590 - val_mse: 0.1396 - val_mape: 136.6973 - lr: 8.0000e-06
# Epoch 87/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0446 - mae: 0.1612 - mse: 0.0446 - mape: 103.7626 - val_loss: 0.1397 - val_mae: 0.2593 - val_mse: 0.1397 - val_mape: 136.9457 - lr: 8.0000e-06
# Epoch 88/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0446 - mae: 0.1609 - mse: 0.0446 - mape: 102.6854 - val_loss: 0.1400 - val_mae: 0.2596 - val_mse: 0.1400 - val_mape: 137.0283 - lr: 8.0000e-06
# Epoch 89/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0450 - mae: 0.1616 - mse: 0.0450 - mape: 103.9400 - val_loss: 0.1399 - val_mae: 0.2596 - val_mse: 0.1399 - val_mape: 137.6000 - lr: 1.6000e-06
# Epoch 90/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0450 - mae: 0.1616 - mse: 0.0450 - mape: 104.9960 - val_loss: 0.1397 - val_mae: 0.2594 - val_mse: 0.1397 - val_mape: 137.7537 - lr: 1.6000e-06
# Epoch 91/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0449 - mae: 0.1615 - mse: 0.0449 - mape: 102.5610 - val_loss: 0.1399 - val_mae: 0.2596 - val_mse: 0.1399 - val_mape: 137.8734 - lr: 1.6000e-06
# Epoch 92/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0447 - mae: 0.1611 - mse: 0.0447 - mape: 102.1311 - val_loss: 0.1398 - val_mae: 0.2595 - val_mse: 0.1398 - val_mape: 137.8719 - lr: 1.6000e-06
# Epoch 93/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0445 - mae: 0.1609 - mse: 0.0445 - mape: 103.7900 - val_loss: 0.1398 - val_mae: 0.2594 - val_mse: 0.1398 - val_mape: 138.0782 - lr: 1.6000e-06
# Epoch 94/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0448 - mae: 0.1611 - mse: 0.0448 - mape: 101.9861 - val_loss: 0.1397 - val_mae: 0.2594 - val_mse: 0.1397 - val_mape: 137.9812 - lr: 1.6000e-06
# Epoch 95/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0451 - mae: 0.1618 - mse: 0.0451 - mape: 104.2211 - val_loss: 0.1397 - val_mae: 0.2593 - val_mse: 0.1397 - val_mape: 138.0796 - lr: 1.6000e-06
# Epoch 96/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0452 - mae: 0.1619 - mse: 0.0452 - mape: 101.5489 - val_loss: 0.1397 - val_mae: 0.2592 - val_mse: 0.1397 - val_mape: 138.0278 - lr: 1.6000e-06
# Epoch 97/100
# 2250/2250 [==============================] - 44s 20ms/step - loss: 0.0449 - mae: 0.1613 - mse: 0.0449 - mape: 102.7199 - val_loss: 0.1398 - val_mae: 0.2593 - val_mse: 0.1398 - val_mape: 137.8476 - lr: 1.6000e-06
# Epoch 98/100
# 2250/2250 [==============================] - 44s 19ms/step - loss: 0.0449 - mae: 0.1613 - mse: 0.0449 - mape: 103.4413 - val_loss: 0.1398 - val_mae: 0.2593 - val_mse: 0.1398 - val_mape: 137.9107 - lr: 1.6000e-06
# Epoch 99/100
# 2250/2250 [==============================] - 43s 19ms/step - loss: 0.0447 - mae: 0.1609 - mse: 0.0447 - mape: 100.4625 - val_loss: 0.1397 - val_mae: 0.2593 - val_mse: 0.1397 - val_mape: 137.9525 - lr: 3.2000e-07
# Epoch 100/100
# 2250/2250 [==============================] - 42s 19ms/step - loss: 0.0446 - mae: 0.1608 - mse: 0.0446 - mape: 101.9188 - val_loss: 0.1398 - val_mae: 0.2594 - val_mse: 0.1398 - val_mape: 137.8769 - lr: 3.2000e-07
# CPU times: user 28min 26s, sys: 7min 9s, total: 35min 36s
# Wall time: 1h 9min 39s

# %% [markdown]
# Save the model weights.

# %%
# save model
model.save_weights('weights/gru.h5', overwrite=True)

# %% [markdown]
# # 3 Error Analysis.

# %% [markdown]
# Run this cell if loading weights.

# %%
# model.load_weights('weights/gru.h5')

# %% [markdown]
# Forecasting and model evaluation

# %%
# model predictions
y_fit = model.predict(x_test)

# evaluate the model using test data
model.evaluate(x_test, y_test)
# Out:
# 241/241 [==============================] - 4s 14ms/step
# 241/241 [==============================] - 5s 18ms/step - loss: 0.1398 - mae: 0.2594 - mse: 0.1398 - mape: 137.8769
# [0.1397646963596344,
#  0.25939831137657166,
#  0.1397646963596344,
#  137.87693786621094]

# %% [markdown]
# Descale the forecasted values.

# %%
# descale the predictions
y_fit = (y_fit * y_std[0]) + y_mean[0]
y_test = (y_test * y_std[0]) + y_mean[0]

# %% [markdown]
# These are the dates where the forecasting starts.
#
# For example, "2016-10-01 02:00:00" means that the first forecasted hour is 2 AM of date 2016-10-01.

# %%
# first forecasted datetime
y_dates = []
for i in range(n_past, len(x) - (n_future + 1)):
    y_dates.append(y.index[i])

# %%
# put results in a dataframe
results = pd.DataFrame(index=y_dates)
results.index.name = 'datetime'
results = results[36000:x_ts.shape[0]]

# %%
# drop results and actual values for all forecasted hours
for h in range(0,y_fit.shape[1]):
  results['fit_' + str(h)] = y_fit[:,h]
  results['actual_' + str(h)] = y_test[:,h]

# %%
results.to_csv('gru_results.csv')

# %% [markdown]
# # 4 Error Graphs

# %%
# plot
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.savefig('gru_training.pdf')

# %%
# plot
plt.figure(figsize=(30,5))
plt.plot(y_test[0:1500,0], label='Actual')
plt.plot(y_fit[0:1500,0], label='Forecast')
plt.xlabel('Hour')
plt.ylabel('Load (MW)')
plt.legend()
plt.grid(True)
plt.savefig('gru_fit.pdf')

# %%
# comparison between predicted and actual values
plt.figure(figsize=(20,10))
a = plt.axes(aspect='equal')
plt.scatter(y_test[:], y_fit[:])
b = np.linspace(*a.get_xlim())
a.plot(b, b, color='black')
plt.xlabel('True Value (MW)')
plt.ylabel('Predictions (MW)')
plt.savefig('gru_comparison.pdf')

# %%
# error histogram
from matplotlib.ticker import PercentFormatter
error = (y_fit - y_test).flatten()
plt.hist(error, bins = 50, weights=np.ones(len(error)) / len(error))
plt.xlabel("Prediction Error (MW)")
_ = plt.ylabel("Percentage")
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.savefig('gru_errordist.pdf')
